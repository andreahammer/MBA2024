# %%
# Data handling and manipulation library
import pandas as pd

# Library for numerical operations in Python
import numpy as np

# %%
""" country = pd.read_csv('Tabel_SKS_Diagnose_country.csv', sep=';')
country.head()
country.shape """
# Out:
# " country = pd.read_csv('Tabel_SKS_Diagnose_country.csv', sep=';')\ncountry.head()\ncountry.shape "

# %%
region = pd.read_csv('Tabel_SKS_Diagnose_region.csv', sep=';')
region.head()
# Out:
#     Aar     SKS                               SKS_Kodetekst Diagnose  \
# 0  2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi   DI702A
# 1  2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi    DM890
# 2  2018  BABZ00               Anlæggelse Af Epiduralkateter    DA419
# 3  2018  BABZ00               Anlæggelse Af Epiduralkateter    DC153
# 4  2018  BABZ00               Anlæggelse Af Epiduralkateter    DC154
#
#              Region  Unikke_Patienter  Registreringer
# 0  1081 Nordjylland                 7            12.0
# 1  1081 Nordjylland                 3             5.0
# 2  1082 Midtjylland                 3             3.0
# 3  1082 Midtjylland                 4             7.0
# 4  1082 Midtjylland                 9            11.0

# %%
hospital = pd.read_csv('Tabel_SKS_Diagnose_hospital.csv', sep=';')
hospital.head()
# Out:
#     Aar     SKS                               SKS_Kodetekst Diagnose  \
# 0  2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi   DI702A
# 1  2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi    DM890
# 2  2018  BABZ00               Anlæggelse Af Epiduralkateter    DC153
# 3  2018  BABZ00               Anlæggelse Af Epiduralkateter    DC154
# 4  2018  BABZ00               Anlæggelse Af Epiduralkateter    DC155
#
#    Sygehuskode                       Sygehus  Unikke_Patienter  Registreringer
# 0         8001  Aalborg Universitetshospital               7.0              12
# 1         8001  Aalborg Universitetshospital               3.0               5
# 2         6620   Aarhus Universitetshospital               4.0               7
# 3         6620   Aarhus Universitetshospital               9.0              11
# 4         6620   Aarhus Universitetshospital              11.0              11

# %%
#country, 
region, hospital
# Out:
# (         Aar     SKS                               SKS_Kodetekst Diagnose  \
#  0       2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi   DI702A
#  1       2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi    DM890
#  2       2018  BABZ00               Anlæggelse Af Epiduralkateter    DA419
#  3       2018  BABZ00               Anlæggelse Af Epiduralkateter    DC153
#  4       2018  BABZ00               Anlæggelse Af Epiduralkateter    DC154
#  ...      ...     ...                                         ...      ...
#  456841  2018  ZZV030           Vurdering Ved Brug Af Spørgeskema    DR429
#  456842  2018  ZZV030           Vurdering Ved Brug Af Spørgeskema    DZ033
#  456843  2018  ZZV030           Vurdering Ved Brug Af Spørgeskema   DZ033A
#  456844  2018  ZZV030           Vurdering Ved Brug Af Spørgeskema    DZ038
#  456845  2018  ZZV030           Vurdering Ved Brug Af Spørgeskema    DZ039
#
#                    Region  Unikke_Patienter  Registreringer
#  0       1081 Nordjylland                 7            12.0
#  1       1081 Nordjylland                 3             5.0
#  2       1082 Midtjylland                 3             3.0
#  3       1082 Midtjylland                 4             7.0
#  4       1082 Midtjylland                 9            11.0
#  ...                  ...               ...             ...
#  456841  1084 Hovedstaden                 3             3.0
#  456842   1083 Syddanmark                 3             3.0
#  456843   1083 Syddanmark                 5             5.0
#  456844  1082 Midtjylland                 5             5.0
#  456845  1082 Midtjylland                 5             5.0
#
#  [456846 rows x 7 columns],
#           Aar             SKS                               SKS_Kodetekst  \
#  0       2018           BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi
#  1       2018           BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi
#  2       2018          BABZ00               Anlæggelse Af Epiduralkateter
#  3       2018          BABZ00               Anlæggelse Af Epiduralkateter
#  4       2018          BABZ00               Anlæggelse Af Epiduralkateter
#  ...      ...             ...                                         ...
#  769291  2018          ZZ0150                            Journaloptagelse
#  769292  2015  Diskretioneret                              Diskretioneret
#  769293  2017  Diskretioneret                              Diskretioneret
#  769294  2018  Diskretioneret                              Diskretioneret
#  769295  2017  Diskretioneret                              Diskretioneret
#
#         Diagnose  Sygehuskode                       Sygehus  Unikke_Patienter  \
#  0        DI702A         8001  Aalborg Universitetshospital               7.0
#  1         DM890         8001  Aalborg Universitetshospital               3.0
#  2         DC153         6620   Aarhus Universitetshospital               4.0
#  3         DC154         6620   Aarhus Universitetshospital               9.0
#  4         DC155         6620   Aarhus Universitetshospital              11.0
#  ...         ...          ...                           ...               ...
#  769291   DZ980C         8887                      Slagelse               3.0
#  769292    DZ988         8887                      Slagelse               6.0
#  769293    DZ988         8887                      Slagelse               8.0
#  769294    DZ988         8887                      Slagelse              17.0
#  769295      NaN         8887                      Slagelse               3.0
#
#          Registreringer
#  0                   12
#  1                    5
#  2                    7
#  3                   11
#  4                   11
#  ...                ...
#  769291               3
#  769292               6
#  769293              49
#  769294              52
#  769295               9
#
#  [769296 rows x 8 columns])

# %%
df = pd.concat([region, hospital], axis=0, ignore_index=True)
df
# Out:
#           Aar             SKS                               SKS_Kodetekst  \
# 0        2018           BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi
# 1        2018           BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi
# 2        2018          BABZ00               Anlæggelse Af Epiduralkateter
# 3        2018          BABZ00               Anlæggelse Af Epiduralkateter
# 4        2018          BABZ00               Anlæggelse Af Epiduralkateter
# ...       ...             ...                                         ...
# 1226137  2018          ZZ0150                            Journaloptagelse
# 1226138  2015  Diskretioneret                              Diskretioneret
# 1226139  2017  Diskretioneret                              Diskretioneret
# 1226140  2018  Diskretioneret                              Diskretioneret
# 1226141  2017  Diskretioneret                              Diskretioneret
#
#         Diagnose            Region  Unikke_Patienter  Registreringer  \
# 0         DI702A  1081 Nordjylland               7.0            12.0
# 1          DM890  1081 Nordjylland               3.0             5.0
# 2          DA419  1082 Midtjylland               3.0             3.0
# 3          DC153  1082 Midtjylland               4.0             7.0
# 4          DC154  1082 Midtjylland               9.0            11.0
# ...          ...               ...               ...             ...
# 1226137   DZ980C               NaN               3.0             3.0
# 1226138    DZ988               NaN               6.0             6.0
# 1226139    DZ988               NaN               8.0            49.0
# 1226140    DZ988               NaN              17.0            52.0
# 1226141      NaN               NaN               3.0             9.0
#
#          Sygehuskode   Sygehus
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
# ...              ...       ...
# 1226137       8887.0  Slagelse
# 1226138       8887.0  Slagelse
# 1226139       8887.0  Slagelse
# 1226140       8887.0  Slagelse
# 1226141       8887.0  Slagelse
#
# [1226142 rows x 9 columns]

# %%
# List of DataFrames
#dfs = [ region, hospital]

kattemad = pd.merge(region, hospital, left_on=["SKS", "Diagnose"], right_on=["SKS", "Diagnose"])


""" combined_df = dfs[0] # hashtag så Jasmin forstår det betyrder at vi combinerer dataframes der starter på 0
for i, df in enumerate(dfs[1:], start=1):
    combined_df = pd.merge(combined_df, df, on=['SKS'], how='outer', suffixes=('', f'_df{i+1}'))
#columns_to_drop = ['brick_nr_df2', 'brick_nr_df3','brick_nr_df4','brick_nr_df5','brick_nr_df6','brick_nr_df7','brick_nr_df8']

# Drop the specified columns
df = combined_df """
kattemad.head()
# Out:
#    Aar_x     SKS                             SKS_Kodetekst_x Diagnose  \
# 0   2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi   DI702A
# 1   2018   BABZ0  Anlæggelse Af Kateter Til Regionalanæstesi    DM890
# 2   2018  BABZ00               Anlæggelse Af Epiduralkateter    DC153
# 3   2018  BABZ00               Anlæggelse Af Epiduralkateter    DC154
# 4   2018  BABZ00               Anlæggelse Af Epiduralkateter    DC155
#
#              Region  Unikke_Patienter_x  Registreringer_x  Aar_y  \
# 0  1081 Nordjylland                   7              12.0   2018
# 1  1081 Nordjylland                   3               5.0   2018
# 2  1082 Midtjylland                   4               7.0   2018
# 3  1082 Midtjylland                   9              11.0   2018
# 4  1082 Midtjylland                  11              11.0   2018
#
#                               SKS_Kodetekst_y  Sygehuskode  \
# 0  Anlæggelse Af Kateter Til Regionalanæstesi         8001
# 1  Anlæggelse Af Kateter Til Regionalanæstesi         8001
# 2               Anlæggelse Af Epiduralkateter         6620
# 3               Anlæggelse Af Epiduralkateter         6620
# 4               Anlæggelse Af Epiduralkateter         6620
#
#                         Sygehus  Unikke_Patienter_y  Registreringer_y
# 0  Aalborg Universitetshospital                 7.0                12
# 1  Aalborg Universitetshospital                 3.0                 5
# 2   Aarhus Universitetshospital                 4.0                 7
# 3   Aarhus Universitetshospital                 9.0                11
# 4   Aarhus Universitetshospital                11.0                11

# %%
dosing = pd.read_csv('Dosing.csv', sep=';')
dosing.head()
# Out:
#       Substance  Dose Index Diagnosis Group
# 0  Certolizumab        4800             PSA
# 1  Certolizumab        4800              RA
# 2    Infliximab        3000              CD
# 3    Infliximab        3000             PSA
# 4    Infliximab        3000              RA

# %%
substances = pd.read_csv('substancesOfInterest.csv', sep=';')
substances.head()
# Out:
#       ATC5       SKS     Substance Medicinkode
# 0  L04AB02  BOHJ18A1    Infliximab    ML04AB02
# 1  L04AB05  BOHJ18A5  Certolizumab    ML04AB05
# 2  L04AC05  BOHJ18B3   Ustekinumab    ML04AC05

# %%
substances, dosing
# Out:
# (      ATC5       SKS     Substance Medicinkode
#  0  L04AB02  BOHJ18A1    Infliximab    ML04AB02
#  1  L04AB05  BOHJ18A5  Certolizumab    ML04AB05
#  2  L04AC05  BOHJ18B3   Ustekinumab    ML04AC05,
#        Substance  Dose Index Diagnosis Group
#  0  Certolizumab        4800             PSA
#  1  Certolizumab        4800              RA
#  2    Infliximab        3000              CD
#  3    Infliximab        3000             PSA
#  4    Infliximab        3000              RA
#  5   Ustekinumab           2              CD)

# %%
pd.merge(dosing, substances, left_on=["Substance"], right_on=["Substance"])
# Out:
#       Substance  Dose Index Diagnosis Group     ATC5       SKS Medicinkode
# 0  Certolizumab        4800             PSA  L04AB05  BOHJ18A5    ML04AB05
# 1  Certolizumab        4800              RA  L04AB05  BOHJ18A5    ML04AB05
# 2    Infliximab        3000              CD  L04AB02  BOHJ18A1    ML04AB02
# 3    Infliximab        3000             PSA  L04AB02  BOHJ18A1    ML04AB02
# 4    Infliximab        3000              RA  L04AB02  BOHJ18A1    ML04AB02
# 5   Ustekinumab           2              CD  L04AC05  BOHJ18B3    ML04AC05

# %%
df = pd.concat([region, hospital], axis=0, ignore_index=True)

# %%
sales_hospital = pd.read_excel('salgs_data_indication_insight_hospital (1).xlsx')
sales_hospital['PRIS'] = sales_hospital['PRIS'].round(2)
sales_hospital.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sales_hospital = pd.read_excel('salgs_data_indication_insight_hospital (1).xlsx')
#       2 sales_hospital['PRIS'] = sales_hospital['PRIS'].round(2)
#       3 sales_hospital.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
sales_pharma = pd.read_csv('salgs_data_indication_insight_pharmacy.csv', sep=';')
column_to_drop = sales_pharma.drop("Unnamed: 10", axis=1)
sales_pharma = column_to_drop
sales_pharma.head()
# Out:
#    Year Month           Region Account Description Product    Size  \
# 0    201003.0  Danmark diverse   0009 GROSSISTSALG  Cimzia  2 stk.
# 1    201006.0  Danmark diverse   0009 GROSSISTSALG  Cimzia  2 stk.
# 2    201007.0  Danmark diverse   0009 GROSSISTSALG  Cimzia  2 stk.
# 3    201011.0  Danmark diverse   0009 GROSSISTSALG  Cimzia  2 stk.
# 4    201103.0  Danmark diverse   0009 GROSSISTSALG  Cimzia  2 stk.
#
#    Size Numeric Strength WHO ATC 5 Code  Volume    Value
# 0           2.0   200 mg        L04AB05     1.0  8083,55
# 1           2.0   200 mg        L04AB05     1.0  8083,55
# 2           2.0   200 mg        L04AB05     1.0  8083,55
# 3           2.0   200 mg        L04AB05     2.0  16167,1
# 4           2.0   200 mg        L04AB05     1.0  8406,89

# %%
df = pd.concat([sales_hospital, sales_pharma], axis=0, ignore_index=True)
#pd.concat(sales_hospital, sales_pharma, left_on=["Product", "Size", "Volume", "Value", "Region", "WHO ATC 5 Code"], right_on=["Product", "Size", "Volume", "Value", "Region", "WHO ATC 5 Code"])

# %%
hospital_account = pd.read_csv('Hospital_Account.csv', sep=";")
column_to_drop_hospital = hospital_account.drop("Unnamed: 4", axis=1)
hospital_account = column_to_drop_hospital

hospital_account["Hospital Code"] = pd.to_numeric(hospital_account["Hospital Code"])
hospital_account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hospital Code  62 non-null     float64
#  1   Hospital       63 non-null     object
#  2   Account        51 non-null     object
#  3   Account no.    50 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 2.1+ KB

# %%
hospital_region = pd.read_csv('Hospital_Region.csv', sep=";")
hospital_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hospital       34 non-null     object
#  1   Region         34 non-null     object
#  2   Hospital Code  34 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 948.0+ bytes

# %%
mjau_mjau_mjau = pd.merge(hospital_account, hospital_region, left_on=["Hospital Code", "Hospital"], right_on=["Hospital Code", "Hospital"])
mjau_new = mjau_mjau_mjau.drop("Account", axis=1)
mjau_new
# Out:
#     Hospital Code                                Hospital  Account no.  \
# 0          2000.0             Hospitalerne I Nordsjælland       4060.0
# 1          1516.0             Herlev Og Gentofte Hospital       4060.0
# 2          1309.0  Bispebjerg Og Frederiksberg Hospitaler       4060.0
# 3          1501.0                       Gentofte Hospital       4060.0
# 4          1301.0                          Rigshospitalet       4060.0
# 5          4001.0                      Bornholms Hospital       4060.0
# 6          1330.0             Amager Og Hvidovre Hospital       4060.0
# 7          1502.0                       Glostrup Hospital       4060.0
# 8          5501.0                     Sydvestjysk Sygehus       4120.0
# 9          6007.0          Fredericia Og Kolding Sygehuse       4120.0
# 10         4202.0         Ouh Odense Universitetshospital       4120.0
# 11         5000.0                   Sygehus Sønderjylland       4120.0
# 12         6008.0                           Vejle Sygehus       4120.0
# 13         8001.0            Aalborg Universitetshospital       4130.0
# 14         6650.0                   Hospitalsenheden Vest       4100.0
# 15         6006.0               Regionshospitalet Horsens       4100.0
# 16         6620.0             Aarhus Universitetshospital       4100.0
# 17         6630.0                     Hospitalsenhed Midt       4100.0
# 18         7005.0               Regionshospitalet Randers       4100.0
# 19         3502.0                        Nykøbing Falster       4070.0
# 20         3501.0                                 Næstved       4070.0
# 21         8881.0                                Roskilde       4070.0
# 22         8882.0                                    Køge       4070.0
# 23         8883.0                                   Fakse       4070.0
# 24         8884.0                                  Holbæk       4070.0
# 25         8885.0                              Kalundborg       4070.0
# 26         8886.0                                 Næstved       4070.0
# 27         8887.0                                Slagelse       4070.0
# 28         8888.0                                Ringsted       4070.0
# 29         8889.0                        Nykøbing Falster       4070.0
# 30         8890.0                                 Nakskov       4070.0
# 31         8891.0                                  Maribo       4070.0
#
#          Region
# 0   Hovedstaden
# 1   Hovedstaden
# 2   Hovedstaden
# 3   Hovedstaden
# 4   Hovedstaden
# 5   Hovedstaden
# 6   Hovedstaden
# 7   Hovedstaden
# 8    Syddanmark
# 9    Syddanmark
# 10   Syddanmark
# 11   Syddanmark
# 12   Syddanmark
# 13  Nordjylland
# 14  Midtjylland
# 15  Midtjylland
# 16  Midtjylland
# 17  Midtjylland
# 18  Midtjylland
# 19     Sjælland
# 20     Sjælland
# 21     Sjælland
# 22     Sjælland
# 23     Sjælland
# 24     Sjælland
# 25     Sjælland
# 26     Sjælland
# 27     Sjælland
# 28     Sjælland
# 29     Sjælland
# 30     Sjælland
# 31     Sjælland

# %%
""" merged_data = pd.merge(sales_pharma, sales_hospital, on="Product", how="left")
merged_data """

""" for index, row in sales_pharma.iterrows():
    product_name = row['Product']
    if product_name in company_name_map:
        products_only.at[index, 'company_name'] = company_name_map[product_name]

# Save the updated products_only dataset
products_only.to_csv("products_only_with_companies.csv", index=False) """

#pd.merge(sales_hospital, sales_pharma, left_on=["Product", "Size", "WHO ATC 5 Code", "Strength"], right_on=["Product", "Size", "WHO ATC 5 Code", "Strength"])
# Out:
# ' for index, row in sales_pharma.iterrows():\n    product_name = row[\'Product\']\n    if product_name in company_name_map:\n        products_only.at[index, \'company_name\'] = company_name_map[product_name]\n\n# Save the updated products_only dataset\nproducts_only.to_csv("products_only_with_companies.csv", index=False) '

# %% [markdown]
# ## Data cleaning and preprocessing
# In the first part of this notebook, the focus will be on preparing and cleaning the data for subsequent analysis. This is an example dataset, and does not provide a full picture of all the datasets.

# %% [markdown]
# #### 1. Get an overview
# We will first investigate the dataframe and look at the value frequency of each column.
#
# This can be used for understanding which column provide enough date to be relevant. Or the correct data type.
#
# Understanding which columns need to be dropped.

# %%
df
# Out:
#        Year Month       Region                       Account Description  \
# 0        201001.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 1        201001.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 2        201001.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 3        201002.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 4        201002.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# ...           ...          ...                                       ...
# 59765         NaN          NaN                                       NaN
# 59766         NaN          NaN                                       NaN
# 59767         NaN          NaN                                       NaN
# 59768         NaN          NaN                                       NaN
# 59769         NaN          NaN                                       NaN
#
#         Product     Company              Size  Size Numeric      Strength  \
# 0        Cimzia  UCB Nordic            2 stk.           2.0        200 mg
# 1      Remicade         MSD  1 htgl. a 100 mg         100.0        100 mg
# 2       Stelara     Janssen             1 stk           1.0  45 mg/0,5 ml
# 3        Cimzia  UCB Nordic            2 stk.           2.0        200 mg
# 4      Remicade         MSD  1 htgl. a 100 mg         100.0        100 mg
# ...         ...         ...               ...           ...           ...
# 59765       NaN         NaN               NaN           NaN           NaN
# 59766       NaN         NaN               NaN           NaN           NaN
# 59767       NaN         NaN               NaN           NaN           NaN
# 59768       NaN         NaN               NaN           NaN           NaN
# 59769       NaN         NaN               NaN           NaN           NaN
#
#       WHO ATC 5 Code  Volume      Value      PRIS
# 0            L04AB05    19.0   160820.1   8464.22
# 1            L04AB02  2096.0  9236652.8   4406.80
# 2            L04AC05    23.0  622716.26  27074.62
# 3            L04AB05    11.0   88919.05   8083.55
# 4            L04AB02  2036.0  8972244.8   4406.80
# ...              ...     ...        ...       ...
# 59765            NaN     NaN        NaN       NaN
# 59766            NaN     NaN        NaN       NaN
# 59767            NaN     NaN        NaN       NaN
# 59768            NaN     NaN        NaN       NaN
# 59769            NaN     NaN        NaN       NaN
#
# [59770 rows x 12 columns]

# %%
#To get a sense of which features offer meaningful information, we print out the frequency of each
#value for each feature
cols_to_drop = []

Nrows = df.shape[0]
# Go through each column except for the ones we want to drop
for col in df.columns.drop(cols_to_drop):
    # get unique values in column
    unique = df[col].unique();
    print("\n", col,":")
    # calculate frequency of each value
    for val in unique:
        if val not in ['nan']:
            N = len(df[df[col] == val])
            print("Value, N observations, frequency :", val," ,", N, " ,", np.round(N/Nrows,3))

    print("No. of NANs ", len(df[df[col].isna()]))
# Out:
#  Year Month :
# Value, N observations, frequency : 201001.0  , 45  , 0.001
# Value, N observations, frequency : 201002.0  , 46  , 0.001
# Value, N observations, frequency : 201003.0  , 53  , 0.001
# Value, N observations, frequency : 201004.0  , 55  , 0.001
# Value, N observations, frequency : 201005.0  , 57  , 0.001
# Value, N observations, frequency : 201006.0  , 62  , 0.001
# Value, N observations, frequency : 201007.0  , 60  , 0.001
# Value, N observations, frequency : 201008.0  , 64  , 0.001
# Value, N observations, frequency : 201009.0  , 65  , 0.001
# Value, N observations, frequency : 201010.0  , 65  , 0.001
# Value, N observations, frequency : 201011.0  , 70  , 0.001
# Value, N observations, frequency : 201012.0  , 72  , 0.001
# Value, N observations, frequency : 201101.0  , 66  , 0.001
# Value, N observations, frequency : 201102.0  , 70  , 0.001
# Value, N observations, frequency : 201103.0  , 73  , 0.001
# Value, N observations, frequency : 201104.0  , 67  , 0.001
# Value, N observations, frequency : 201105.0  , 68  , 0.001
# Value, N observations, frequency : 201106.0  , 99  , 0.002
# Value, N observations, frequency : 201107.0  , 76  , 0.001
# Value, N observations, frequency : 201108.0  , 82  , 0.001
# Value, N observations, frequency : 201109.0  , 78  , 0.001
# Value, N observations, frequency : 201110.0  , 81  , 0.001
# Value, N observations, frequency : 201111.0  , 81  , 0.001
# Value, N observations, frequency : 201112.0  , 85  , 0.001
# Value, N observations, frequency : 201201.0  , 81  , 0.001
# Value, N observations, frequency : 201202.0  , 76  , 0.001
# Value, N observations, frequency : 201203.0  , 86  , 0.001
# Value, N observations, frequency : 201204.0  , 76  , 0.001
# Value, N observations, frequency : 201205.0  , 84  , 0.001
# Value, N observations, frequency : 201206.0  , 76  , 0.001
# Value, N observations, frequency : 201207.0  , 86  , 0.001
# Value, N observations, frequency : 201208.0  , 81  , 0.001
# Value, N observations, frequency : 201209.0  , 71  , 0.001
# Value, N observations, frequency : 201210.0  , 83  , 0.001
# Value, N observations, frequency : 201211.0  , 91  , 0.002
# Value, N observations, frequency : 201212.0  , 83  , 0.001
# Value, N observations, frequency : 201301.0  , 78  , 0.001
# Value, N observations, frequency : 201302.0  , 83  , 0.001
# Value, N observations, frequency : 201303.0  , 79  , 0.001
# Value, N observations, frequency : 201304.0  , 94  , 0.002
# Value, N observations, frequency : 201305.0  , 90  , 0.002
# Value, N observations, frequency : 201306.0  , 91  , 0.002
# Value, N observations, frequency : 201307.0  , 76  , 0.001
# Value, N observations, frequency : 201308.0  , 91  , 0.002
# Value, N observations, frequency : 201309.0  , 85  , 0.001
# Value, N observations, frequency : 201310.0  , 81  , 0.001
# Value, N observations, frequency : 201311.0  , 93  , 0.002
# Value, N observations, frequency : 201312.0  , 85  , 0.001
# Value, N observations, frequency : 201401.0  , 76  , 0.001
# Value, N observations, frequency : 201402.0  , 81  , 0.001
# Value, N observations, frequency : 201403.0  , 76  , 0.001
# Value, N observations, frequency : 201404.0  , 81  , 0.001
# Value, N observations, frequency : 201405.0  , 81  , 0.001
# Value, N observations, frequency : 201406.0  , 81  , 0.001
# Value, N observations, frequency : 201407.0  , 83  , 0.001
# Value, N observations, frequency : 201408.0  , 86  , 0.001
# Value, N observations, frequency : 201409.0  , 81  , 0.001
# Value, N observations, frequency : 201410.0  , 80  , 0.001
# Value, N observations, frequency : 201411.0  , 87  , 0.001
# Value, N observations, frequency : 201412.0  , 80  , 0.001
# Value, N observations, frequency : 201501.0  , 83  , 0.001
# Value, N observations, frequency : 201502.0  , 99  , 0.002
# Value, N observations, frequency : 201503.0  , 99  , 0.002
# Value, N observations, frequency : 201504.0  , 112  , 0.002
# Value, N observations, frequency : 201505.0  , 106  , 0.002
# Value, N observations, frequency : 201506.0  , 107  , 0.002
# Value, N observations, frequency : 201507.0  , 99  , 0.002
# Value, N observations, frequency : 201508.0  , 106  , 0.002
# Value, N observations, frequency : 201509.0  , 109  , 0.002
# Value, N observations, frequency : 201510.0  , 106  , 0.002
# Value, N observations, frequency : 201511.0  , 101  , 0.002
# Value, N observations, frequency : 201512.0  , 119  , 0.002
# Value, N observations, frequency : 201601.0  , 99  , 0.002
# Value, N observations, frequency : 201602.0  , 109  , 0.002
# Value, N observations, frequency : 201603.0  , 108  , 0.002
# Value, N observations, frequency : 201604.0  , 112  , 0.002
# Value, N observations, frequency : 201605.0  , 106  , 0.002
# Value, N observations, frequency : 201606.0  , 106  , 0.002
# Value, N observations, frequency : 201607.0  , 99  , 0.002
# Value, N observations, frequency : 201608.0  , 105  , 0.002
# Value, N observations, frequency : 201609.0  , 118  , 0.002
# Value, N observations, frequency : 201610.0  , 96  , 0.002
# Value, N observations, frequency : 201611.0  , 115  , 0.002
# Value, N observations, frequency : 201612.0  , 109  , 0.002
# Value, N observations, frequency : 201701.0  , 87  , 0.001
# Value, N observations, frequency : 201702.0  , 98  , 0.002
# Value, N observations, frequency : 201703.0  , 123  , 0.002
# Value, N observations, frequency : 201704.0  , 117  , 0.002
# Value, N observations, frequency : 201705.0  , 123  , 0.002
# Value, N observations, frequency : 201706.0  , 138  , 0.002
# Value, N observations, frequency : 201707.0  , 125  , 0.002
# Value, N observations, frequency : 201708.0  , 127  , 0.002
# Value, N observations, frequency : 201709.0  , 127  , 0.002
# Value, N observations, frequency : 201710.0  , 122  , 0.002
# Value, N observations, frequency : 201711.0  , 121  , 0.002
# Value, N observations, frequency : 201712.0  , 130  , 0.002
# Value, N observations, frequency : 201801.0  , 108  , 0.002
# Value, N observations, frequency : 201802.0  , 114  , 0.002
# Value, N observations, frequency : 201803.0  , 120  , 0.002
# Value, N observations, frequency : 201804.0  , 118  , 0.002
# Value, N observations, frequency : 201805.0  , 126  , 0.002
# Value, N observations, frequency : 201806.0  , 123  , 0.002
# Value, N observations, frequency : 201807.0  , 113  , 0.002
# Value, N observations, frequency : 201808.0  , 120  , 0.002
# Value, N observations, frequency : 201809.0  , 116  , 0.002
# Value, N observations, frequency : 201810.0  , 113  , 0.002
# Value, N observations, frequency : 201811.0  , 114  , 0.002
# Value, N observations, frequency : 201812.0  , 126  , 0.002
# Value, N observations, frequency : 201901.0  , 99  , 0.002
# Value, N observations, frequency : 201902.0  , 108  , 0.002
# Value, N observations, frequency : 201903.0  , 115  , 0.002
# Value, N observations, frequency : 201904.0  , 118  , 0.002
# Value, N observations, frequency : 201905.0  , 125  , 0.002
# Value, N observations, frequency : 201906.0  , 124  , 0.002
# Value, N observations, frequency : 201907.0  , 121  , 0.002
# Value, N observations, frequency : 201908.0  , 109  , 0.002
# Value, N observations, frequency : 201909.0  , 120  , 0.002
# Value, N observations, frequency : 201910.0  , 136  , 0.002
# Value, N observations, frequency : 201911.0  , 143  , 0.002
# Value, N observations, frequency : 201912.0  , 130  , 0.002
# Value, N observations, frequency : 202001.0  , 125  , 0.002
# Value, N observations, frequency : 202002.0  , 113  , 0.002
# Value, N observations, frequency : 202003.0  , 127  , 0.002
# Value, N observations, frequency : 202004.0  , 120  , 0.002
# Value, N observations, frequency : 202005.0  , 118  , 0.002
# Value, N observations, frequency : 202006.0  , 125  , 0.002
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  Region :
# Value, N observations, frequency : Hovedstaden  , 1434  , 0.024
# Value, N observations, frequency : Sjælland  , 2747  , 0.046
# Value, N observations, frequency : Midtjylland  , 2125  , 0.036
# Value, N observations, frequency : Syddanmark  , 4171  , 0.07
# Value, N observations, frequency : Nordjylland  , 1393  , 0.023
# Value, N observations, frequency : Danmark diverse  , 10  , 0.0
# Value, N observations, frequency : Færøerne  , 286  , 0.005
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  Account Description :
# Value, N observations, frequency : 4060 Centralapoteket, Region Hovedstaden  , 1306  , 0.022
# Value, N observations, frequency : 4070 Sjællands Universitetshospital, Roskilde  , 1144  , 0.019
# Value, N observations, frequency : 4090 Holbæk Sygehus, apoteket  , 100  , 0.002
# Value, N observations, frequency : 4091 Slagelse Sygehus, apoteksfilial  , 128  , 0.002
# Value, N observations, frequency : 4100 Århus Kommunehospitalet, apoteket  , 1204  , 0.02
# Value, N observations, frequency : 4120 Odense Universitetshospital  , 1140  , 0.019
# Value, N observations, frequency : 4130 Aalborg Sygehus, apoteket  , 822  , 0.014
# Value, N observations, frequency : 4160 Kolding Sygehus, apoteket  , 748  , 0.013
# Value, N observations, frequency : 4170 Vejle Sygehus, apoteket  , 496  , 0.008
# Value, N observations, frequency : 4375 Nykøbing F. sygehus, apoteket  , 346  , 0.006
# Value, N observations, frequency : 4376 Næstved Sygehus, apoteket  , 560  , 0.009
# Value, N observations, frequency : 4378 Esbjerg Centralsygehus, apoteket  , 692  , 0.012
# Value, N observations, frequency : 4379 Herning Centralsygehus, apoteket  , 108  , 0.002
# Value, N observations, frequency : 4397 Sønderborg Sygehus, apoteket  , 592  , 0.01
# Value, N observations, frequency : 4398 Viborg Sygehus, apoteket  , 188  , 0.003
# Value, N observations, frequency : 0009 GROSSISTSALG  , 10  , 0.0
# Value, N observations, frequency : 0030 Viborg Svane apotek  , 13  , 0.0
# Value, N observations, frequency : 0060 Århus Løve apotek  , 137  , 0.002
# Value, N observations, frequency : 0070 Sorø apotek  , 10  , 0.0
# Value, N observations, frequency : 0080 Ribe apotek  , 41  , 0.001
# Value, N observations, frequency : 0111 Kristrup Løve Apotek  , 5  , 0.0
# Value, N observations, frequency : 0120 Næstved Løve apotek  , 24  , 0.0
# Value, N observations, frequency : 0130 Nakskov Løve apotek  , 27  , 0.0
# Value, N observations, frequency : 0140 Køge Torvets apotek  , 92  , 0.002
# Value, N observations, frequency : 0142 Solrød apotek  , 10  , 0.0
# Value, N observations, frequency : 0170 Roskilde Dom Apotek  , 16  , 0.0
# Value, N observations, frequency : 0180 Løve Apotek Nykøbing F.  , 1  , 0.0
# Value, N observations, frequency : 0181 Løve Apotek Nysted  , 16  , 0.0
# Value, N observations, frequency : 0250 Maribo apotek  , 17  , 0.0
# Value, N observations, frequency : 0310 København Vaisenhus apotek  , 2  , 0.0
# Value, N observations, frequency : 0320 Vordingborg apotek  , 40  , 0.001
# Value, N observations, frequency : 0360 Vejle Løve apotek  , 38  , 0.001
# Value, N observations, frequency : 0380 Ringkøbing Løve apotek  , 19  , 0.0
# Value, N observations, frequency : 0391 Fjerritslev Apotek  , 16  , 0.0
# Value, N observations, frequency : 0450 Hjørring Løve apotek  , 6  , 0.0
# Value, N observations, frequency : 0510 Varde apotek  , 70  , 0.001
# Value, N observations, frequency : 0511 Varde Østervold Apotek  , 4  , 0.0
# Value, N observations, frequency : 0521 Vestergade Apotek  , 3  , 0.0
# Value, N observations, frequency : 0540 Hobro apotek  , 1  , 0.0
# Value, N observations, frequency : 0560 Sakskøbing apotek  , 23  , 0.0
# Value, N observations, frequency : 0600 Skanderborg apotek  , 27  , 0.0
# Value, N observations, frequency : 0602 Skanderborg Apotek - Filial Bloms  , 14  , 0.0
# Value, N observations, frequency : 0620 Nykøbing apotek  , 1  , 0.0
# Value, N observations, frequency : 0630 Aalborg Løve apotek  , 11  , 0.0
# Value, N observations, frequency : 0660 Frederikshavn Løve apotek  , 29  , 0.0
# Value, N observations, frequency : 0690 Sæby apotek  , 20  , 0.0
# Value, N observations, frequency : 0701 Kolind Apotek  , 2  , 0.0
# Value, N observations, frequency : 0770 Ringsted apotek  , 1  , 0.0
# Value, N observations, frequency : 0771 Klosterparkens Apotek  , 1  , 0.0
# Value, N observations, frequency : 0780 Herning Løve apotek  , 16  , 0.0
# Value, N observations, frequency : 0781 Tinghus Apoteket  , 1  , 0.0
# Value, N observations, frequency : 0790 Hørsholm apotek  , 5  , 0.0
# Value, N observations, frequency : 0792 Apoteket Egevangen  , 1  , 0.0
# Value, N observations, frequency : 0800 Frederiksværk apotek  , 3  , 0.0
# Value, N observations, frequency : 0860 Præstø apotek  , 7  , 0.0
# Value, N observations, frequency : 0870 Hammel Frijsenborg apotek  , 25  , 0.0
# Value, N observations, frequency : 0880 Grindsted apotek  , 22  , 0.0
# Value, N observations, frequency : 0890 Silkeborg Ørne apotek  , 15  , 0.0
# Value, N observations, frequency : 0920 Nørresundby apotek  , 30  , 0.001
# Value, N observations, frequency : 0922 Vodskov Apotek  , 7  , 0.0
# Value, N observations, frequency : 0923 Solsidens Apotek  , 4  , 0.0
# Value, N observations, frequency : 0960 Odder apotek  , 1  , 0.0
# Value, N observations, frequency : 0962 Malling Apotek  , 10  , 0.0
# Value, N observations, frequency : 0981 Ølgod Apotek  , 10  , 0.0
# Value, N observations, frequency : 1000 Haslev apotek  , 33  , 0.001
# Value, N observations, frequency : 1040 Hornslet apotek  , 10  , 0.0
# Value, N observations, frequency : 1041 Auning Apotek  , 18  , 0.0
# Value, N observations, frequency : 1090 Glostrup apotek  , 34  , 0.001
# Value, N observations, frequency : 1110 Frederiksberg apotek  , 11  , 0.0
# Value, N observations, frequency : 1131 Hornbæk apotek  , 4  , 0.0
# Value, N observations, frequency : 1151 Brande Apotek  , 5  , 0.0
# Value, N observations, frequency : 1180 Horsens Svane apotek  , 3  , 0.0
# Value, N observations, frequency : 1211 Søndersø Apotek  , 8  , 0.0
# Value, N observations, frequency : 1240 Nørre-Nebel apotek  , 25  , 0.0
# Value, N observations, frequency : 1290 Galten apotek  , 29  , 0.0
# Value, N observations, frequency : 1320 Århus Jernbane apotek  , 8  , 0.0
# Value, N observations, frequency : 1360 Nykøbing F. Svane apotek  , 32  , 0.001
# Value, N observations, frequency : 1370 Glumsø apotek  , 14  , 0.0
# Value, N observations, frequency : 1430 Roslev apotek  , 1  , 0.0
# Value, N observations, frequency : 1431 Balling Apotek  , 17  , 0.0
# Value, N observations, frequency : 1440 Dronninglund Apotek  , 21  , 0.0
# Value, N observations, frequency : 1441 Hals apotek  , 27  , 0.0
# Value, N observations, frequency : 1500 Struer apotek  , 5  , 0.0
# Value, N observations, frequency : 1560 Uldum apotek  , 3  , 0.0
# Value, N observations, frequency : 1580 Esbjerg Krone Apotek  , 93  , 0.002
# Value, N observations, frequency : 1640 Hadsten apotek  , 10  , 0.0
# Value, N observations, frequency : 1660 Horsens Løve apotek  , 1  , 0.0
# Value, N observations, frequency : 1690 Slagelse Rådhusapoteket  , 14  , 0.0
# Value, N observations, frequency : 1720 Brønderslev Apotek  , 42  , 0.001
# Value, N observations, frequency : 1722 Brønderslev Løve Apotek  , 5  , 0.0
# Value, N observations, frequency : 1730 Tjaldurs Apotek  , 234  , 0.004
# Value, N observations, frequency : 1732 Suduroyar Apotek  , 6  , 0.0
# Value, N observations, frequency : 1733 Eysturoyar Apotek  , 4  , 0.0
# Value, N observations, frequency : 1736 Nordoya Apotek  , 42  , 0.001
# Value, N observations, frequency : 1780 Århus Vejlby apotek  , 20  , 0.0
# Value, N observations, frequency : 1782 Veri Apotek  , 5  , 0.0
# Value, N observations, frequency : 1783 Egå Apotek  , 10  , 0.0
# Value, N observations, frequency : 1810 Aalborg Budolfi apotek  , 50  , 0.001
# Value, N observations, frequency : 1811 Nibe Apotek  , 9  , 0.0
# Value, N observations, frequency : 1812 Løgstør Apotek  , 4  , 0.0
# Value, N observations, frequency : 1820 Hellerup apotek  , 1  , 0.0
# Value, N observations, frequency : 2000 Vejen apotek  , 25  , 0.0
# Value, N observations, frequency : 2001 Vejen Trolde Apotek  , 1  , 0.0
# Value, N observations, frequency : 2020 København Øresunds apotek  , 1  , 0.0
# Value, N observations, frequency : 2040 Silkeborg Himmelbjerg apotek  , 27  , 0.0
# Value, N observations, frequency : 2070 Stenlille apotek  , 7  , 0.0
# Value, N observations, frequency : 2120 Skagen apotek  , 31  , 0.001
# Value, N observations, frequency : 2160 Asnæs Apotek  , 19  , 0.0
# Value, N observations, frequency : 2180 Hadsund apotek  , 6  , 0.0
# Value, N observations, frequency : 2200 Skørping apotek  , 16  , 0.0
# Value, N observations, frequency : 2201 Støvring apotek  , 29  , 0.0
# Value, N observations, frequency : 2250 Ballerup Apotek  , 6  , 0.0
# Value, N observations, frequency : 2330 Esbjerg Neptun Apotek  , 12  , 0.0
# Value, N observations, frequency : 2331 Sædding apotek  , 13  , 0.0
# Value, N observations, frequency : 2410 Århus Marselisborg apotek  , 37  , 0.001
# Value, N observations, frequency : 2470 Thisted Løve apotek  , 9  , 0.0
# Value, N observations, frequency : 2480 Hedensted apotek  , 20  , 0.0
# Value, N observations, frequency : 2490 Ikast apotek  , 3  , 0.0
# Value, N observations, frequency : 2491 Ikast Apotek Vest  , 1  , 0.0
# Value, N observations, frequency : 2530 Bramminge Apotek  , 67  , 0.001
# Value, N observations, frequency : 2532 Holsted apotek  , 7  , 0.0
# Value, N observations, frequency : 2550 Aalborg Reberbane apotek  , 8  , 0.0
# Value, N observations, frequency : 2551 Hasseris Apotek  , 14  , 0.0
# Value, N observations, frequency : 2590 Aars apotek  , 60  , 0.001
# Value, N observations, frequency : 2620 Gammel Kongevej apotek  , 1  , 0.0
# Value, N observations, frequency : 2810 Herning Østergades apotek  , 12  , 0.0
# Value, N observations, frequency : 2811 Apoteket HerningCentret  , 1  , 0.0
# Value, N observations, frequency : 2830 Holte apotek  , 1  , 0.0
# Value, N observations, frequency : 3020 Tønder Løve apotek  , 1  , 0.0
# Value, N observations, frequency : 3022 Løgumkloster apotek  , 3  , 0.0
# Value, N observations, frequency : 3040 Ulve Apoteket - Kolding Sønderbro  , 38  , 0.001
# Value, N observations, frequency : 3060 Aalborg Vejgaard apotek  , 29  , 0.0
# Value, N observations, frequency : 3061 Aalborg Ø Fyrkilden  , 20  , 0.0
# Value, N observations, frequency : 3130 Frederikshavn Svane apotek  , 3  , 0.0
# Value, N observations, frequency : 3160 Nyborg apotek  , 1  , 0.0
# Value, N observations, frequency : 3170 Århus Trøjborg apotek  , 49  , 0.001
# Value, N observations, frequency : 3230 Tårnby apotek  , 2  , 0.0
# Value, N observations, frequency : 3260 Randers Sønderbros apotek  , 3  , 0.0
# Value, N observations, frequency : 3372 Hasle Apotek  , 4  , 0.0
# Value, N observations, frequency : 3390 Rødovre apotek  , 1  , 0.0
# Value, N observations, frequency : 3480 Hvidovre apotek  , 5  , 0.0
# Value, N observations, frequency : 3530 Bagsværd Apotek  , 3  , 0.0
# Value, N observations, frequency : 3561 Sindal apotek  , 3  , 0.0
# Value, N observations, frequency : 3580 Buddinge Apotek  , 6  , 0.0
# Value, N observations, frequency : 3610 Aalborg Aalborghus apotek  , 28  , 0.0
# Value, N observations, frequency : 3611 Aalborg Storcenter Apotek  , 1  , 0.0
# Value, N observations, frequency : 3630 Esbjerg Jerne Apotek  , 2  , 0.0
# Value, N observations, frequency : 3632 Hjerting Apotek  , 19  , 0.0
# Value, N observations, frequency : 3650 Hundige apotek  , 37  , 0.001
# Value, N observations, frequency : 3651 Ishøj apotek  , 39  , 0.001
# Value, N observations, frequency : 3660 Århus City-Vest apotek  , 10  , 0.0
# Value, N observations, frequency : 3661 Tilst Apotek  , 28  , 0.0
# Value, N observations, frequency : 3680 Køge Boholte Apotek  , 1  , 0.0
# Value, N observations, frequency : 3681 Ølby Apotek  , 1  , 0.0
# Value, N observations, frequency : 3690 Stenløse apotek  , 2  , 0.0
# Value, N observations, frequency : 3700 Greve apotek  , 12  , 0.0
# Value, N observations, frequency : 3701 Tune Apotek  , 8  , 0.0
# Value, N observations, frequency : 3702 Havdrup apotek  , 5  , 0.0
# Value, N observations, frequency : 3710 Åbybro Apotek  , 14  , 0.0
# Value, N observations, frequency : 3711 Brovst Apotek  , 3  , 0.0
# Value, N observations, frequency : 3712 Løkken Apotek  , 11  , 0.0
# Value, N observations, frequency : 3713 Pandrup Apotek  , 4  , 0.0
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  Product :
# Value, N observations, frequency : Cimzia  , 2565  , 0.043
# Value, N observations, frequency : Remicade  , 2841  , 0.048
# Value, N observations, frequency : Stelara  , 5197  , 0.087
# Value, N observations, frequency : Remsima  , 823  , 0.014
# Value, N observations, frequency : Inflectra  , 394  , 0.007
# Value, N observations, frequency : Zessly  , 346  , 0.006
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  Company :
# Value, N observations, frequency : UCB Nordic  , 1224  , 0.02
# Value, N observations, frequency : MSD  , 1360  , 0.023
# Value, N observations, frequency : Janssen  , 1421  , 0.024
# Value, N observations, frequency : Orion Pharma  , 411  , 0.007
# Value, N observations, frequency : Pfizer  , 197  , 0.003
# Value, N observations, frequency : Sandoz  , 173  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  54984
#
#  Size :
# Value, N observations, frequency : 2 stk.  , 2565  , 0.043
# Value, N observations, frequency : 1 htgl. a 100 mg  , 566  , 0.009
# Value, N observations, frequency : 1 stk  , 100  , 0.002
# Value, N observations, frequency : 1  eng. spr. a 1 ml  , 2188  , 0.037
# Value, N observations, frequency : 1 stk.  (0,5 ml)  , 2456  , 0.041
# Value, N observations, frequency : 1 htgl.  , 2243  , 0.038
# Value, N observations, frequency : 1 htgl. (Paranova)  , 32  , 0.001
# Value, N observations, frequency : 1 stk.  , 1828  , 0.031
# Value, N observations, frequency : 3 stk.  , 164  , 0.003
# Value, N observations, frequency : 1 stk.  (0,5 ml)(EuroPharmaDK)  , 16  , 0.0
# Value, N observations, frequency : 1 stk. (0,5 ml) (Orifarm)  , 8  , 0.0
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  Size Numeric :
# Value, N observations, frequency : 2.0  , 2565  , 0.043
# Value, N observations, frequency : 100.0  , 566  , 0.009
# Value, N observations, frequency : 1.0  , 8871  , 0.148
# Value, N observations, frequency : 3.0  , 164  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  Strength :
# Value, N observations, frequency : 200 mg  , 2515  , 0.042
# Value, N observations, frequency : 100 mg  , 4404  , 0.074
# Value, N observations, frequency : 45 mg/0,5 ml  , 100  , 0.002
# Value, N observations, frequency : 90 mg  , 2188  , 0.037
# Value, N observations, frequency : 45 mg  , 2480  , 0.041
# Value, N observations, frequency : 130 mg  , 429  , 0.007
# Value, N observations, frequency : 200 mg/ml  , 50  , 0.001
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  WHO ATC 5 Code :
# Value, N observations, frequency : L04AB05  , 2565  , 0.043
# Value, N observations, frequency : L04AB02  , 4404  , 0.074
# Value, N observations, frequency : L04AC05  , 5197  , 0.087
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  Volume :
# Value, N observations, frequency : 19.0  , 64  , 0.001
# Value, N observations, frequency : 2096.0  , 2  , 0.0
# Value, N observations, frequency : 23.0  , 58  , 0.001
# Value, N observations, frequency : 11.0  , 84  , 0.001
# Value, N observations, frequency : 2036.0  , 2  , 0.0
# Value, N observations, frequency : 28.0  , 68  , 0.001
# Value, N observations, frequency : 14.0  , 93  , 0.002
# Value, N observations, frequency : 2512.0  , 2  , 0.0
# Value, N observations, frequency : 41.0  , 30  , 0.001
# Value, N observations, frequency : 24.0  , 63  , 0.001
# Value, N observations, frequency : 2011.0  , 2  , 0.0
# Value, N observations, frequency : 60.0  , 192  , 0.003
# Value, N observations, frequency : 10.0  , 274  , 0.005
# Value, N observations, frequency : 2599.0  , 2  , 0.0
# Value, N observations, frequency : 20.0  , 280  , 0.005
# Value, N observations, frequency : 29.0  , 36  , 0.001
# Value, N observations, frequency : 5.0  , 199  , 0.003
# Value, N observations, frequency : 34.0  , 52  , 0.001
# Value, N observations, frequency : 2020.0  , 2  , 0.0
# Value, N observations, frequency : 17.0  , 68  , 0.001
# Value, N observations, frequency : 26.0  , 78  , 0.001
# Value, N observations, frequency : 18.0  , 83  , 0.001
# Value, N observations, frequency : 1998.0  , 6  , 0.0
# Value, N observations, frequency : 16.0  , 111  , 0.002
# Value, N observations, frequency : 2630.0  , 2  , 0.0
# Value, N observations, frequency : 15.0  , 118  , 0.002
# Value, N observations, frequency : 2010.0  , 2  , 0.0
# Value, N observations, frequency : 22.0  , 74  , 0.001
# Value, N observations, frequency : 2000.0  , 16  , 0.0
# Value, N observations, frequency : 7.0  , 102  , 0.002
# Value, N observations, frequency : 2103.0  , 2  , 0.0
# Value, N observations, frequency : 27.0  , 46  , 0.001
# Value, N observations, frequency : 2151.0  , 2  , 0.0
# Value, N observations, frequency : 30.0  , 214  , 0.004
# Value, N observations, frequency : 21.0  , 60  , 0.001
# Value, N observations, frequency : 2510.0  , 2  , 0.0
# Value, N observations, frequency : 1.0  , 2114  , 0.035
# Value, N observations, frequency : 1835.0  , 2  , 0.0
# Value, N observations, frequency : 6.0  , 268  , 0.004
# Value, N observations, frequency : 2617.0  , 2  , 0.0
# Value, N observations, frequency : 1599.0  , 2  , 0.0
# Value, N observations, frequency : 2415.0  , 2  , 0.0
# Value, N observations, frequency : 36.0  , 36  , 0.001
# Value, N observations, frequency : 1600.0  , 4  , 0.0
# Value, N observations, frequency : 800.0  , 2  , 0.0
# Value, N observations, frequency : 1620.0  , 4  , 0.0
# Value, N observations, frequency : 37.0  , 35  , 0.001
# Value, N observations, frequency : 3442.0  , 2  , 0.0
# Value, N observations, frequency : 8.0  , 198  , 0.003
# Value, N observations, frequency : 1636.0  , 2  , 0.0
# Value, N observations, frequency : 31.0  , 33  , 0.001
# Value, N observations, frequency : 2440.0  , 2  , 0.0
# Value, N observations, frequency : 2424.0  , 2  , 0.0
# Value, N observations, frequency : 63.0  , 8  , 0.0
# Value, N observations, frequency : 79.0  , 6  , 0.0
# Value, N observations, frequency : 2827.0  , 4  , 0.0
# Value, N observations, frequency : 68.0  , 14  , 0.0
# Value, N observations, frequency : 2446.0  , 2  , 0.0
# Value, N observations, frequency : 82.0  , 10  , 0.0
# Value, N observations, frequency : 1632.0  , 2  , 0.0
# Value, N observations, frequency : 32.0  , 50  , 0.001
# Value, N observations, frequency : 80.0  , 133  , 0.002
# Value, N observations, frequency : 2629.0  , 2  , 0.0
# Value, N observations, frequency : 25.0  , 81  , 0.001
# Value, N observations, frequency : 90.0  , 65  , 0.001
# Value, N observations, frequency : 1625.0  , 2  , 0.0
# Value, N observations, frequency : 110.0  , 35  , 0.001
# Value, N observations, frequency : 2430.0  , 2  , 0.0
# Value, N observations, frequency : 50.0  , 155  , 0.003
# Value, N observations, frequency : 1809.0  , 2  , 0.0
# Value, N observations, frequency : 44.0  , 28  , 0.0
# Value, N observations, frequency : 100.0  , 75  , 0.001
# Value, N observations, frequency : 3040.0  , 2  , 0.0
# Value, N observations, frequency : 43.0  , 22  , 0.0
# Value, N observations, frequency : 2030.0  , 2  , 0.0
# Value, N observations, frequency : 122.0  , 7  , 0.0
# Value, N observations, frequency : 2049.0  , 2  , 0.0
# Value, N observations, frequency : 38.0  , 47  , 0.001
# Value, N observations, frequency : 35.0  , 44  , 0.001
# Value, N observations, frequency : 150.0  , 88  , 0.001
# Value, N observations, frequency : 7030.0  , 2  , 0.0
# Value, N observations, frequency : 120.0  , 86  , 0.001
# Value, N observations, frequency : 39.0  , 32  , 0.001
# Value, N observations, frequency : 33.0  , 31  , 0.001
# Value, N observations, frequency : 236.0  , 2  , 0.0
# Value, N observations, frequency : 160.0  , 116  , 0.002
# Value, N observations, frequency : 2024.0  , 4  , 0.0
# Value, N observations, frequency : 48.0  , 68  , 0.001
# Value, N observations, frequency : 240.0  , 86  , 0.001
# Value, N observations, frequency : 226.0  , 2  , 0.0
# Value, N observations, frequency : 67.0  , 10  , 0.0
# Value, N observations, frequency : 200.0  , 43  , 0.001
# Value, N observations, frequency : 2006.0  , 2  , 0.0
# Value, N observations, frequency : 45.0  , 47  , 0.001
# Value, N observations, frequency : 220.0  , 14  , 0.0
# Value, N observations, frequency : 3000.0  , 24  , 0.0
# Value, N observations, frequency : 310.0  , 8  , 0.0
# Value, N observations, frequency : 53.0  , 26  , 0.0
# Value, N observations, frequency : 233.0  , 2  , 0.0
# Value, N observations, frequency : 2035.0  , 2  , 0.0
# Value, N observations, frequency : 49.0  , 20  , 0.0
# Value, N observations, frequency : 326.0  , 2  , 0.0
# Value, N observations, frequency : 256.0  , 22  , 0.0
# Value, N observations, frequency : 2070.0  , 4  , 0.0
# Value, N observations, frequency : 40.0  , 227  , 0.004
# Value, N observations, frequency : 500.0  , 10  , 0.0
# Value, N observations, frequency : 6000.0  , 2  , 0.0
# Value, N observations, frequency : 65.0  , 33  , 0.001
# Value, N observations, frequency : 75.0  , 26  , 0.0
# Value, N observations, frequency : 133.0  , 8  , 0.0
# Value, N observations, frequency : 134.0  , 2  , 0.0
# Value, N observations, frequency : 350.0  , 14  , 0.0
# Value, N observations, frequency : 249.0  , 2  , 0.0
# Value, N observations, frequency : 300.0  , 62  , 0.001
# Value, N observations, frequency : 1999.0  , 4  , 0.0
# Value, N observations, frequency : 46.0  , 26  , 0.0
# Value, N observations, frequency : 57.0  , 18  , 0.0
# Value, N observations, frequency : 54.0  , 22  , 0.0
# Value, N observations, frequency : 320.0  , 28  , 0.0
# Value, N observations, frequency : 280.0  , 36  , 0.001
# Value, N observations, frequency : 360.0  , 22  , 0.0
# Value, N observations, frequency : 2050.0  , 2  , 0.0
# Value, N observations, frequency : 73.0  , 13  , 0.0
# Value, N observations, frequency : 460.0  , 4  , 0.0
# Value, N observations, frequency : 3015.0  , 2  , 0.0
# Value, N observations, frequency : 1020.0  , 4  , 0.0
# Value, N observations, frequency : 1400.0  , 8  , 0.0
# Value, N observations, frequency : 6070.0  , 2  , 0.0
# Value, N observations, frequency : 151.0  , 4  , 0.0
# Value, N observations, frequency : 3.0  , 314  , 0.005
# Value, N observations, frequency : 1000.0  , 6  , 0.0
# Value, N observations, frequency : 415.0  , 2  , 0.0
# Value, N observations, frequency : 1312.0  , 2  , 0.0
# Value, N observations, frequency : 2146.0  , 2  , 0.0
# Value, N observations, frequency : 480.0  , 86  , 0.001
# Value, N observations, frequency : 1700.0  , 2  , 0.0
# Value, N observations, frequency : 102.0  , 4  , 0.0
# Value, N observations, frequency : 84.0  , 10  , 0.0
# Value, N observations, frequency : 450.0  , 12  , 0.0
# Value, N observations, frequency : 3100.0  , 4  , 0.0
# Value, N observations, frequency : 56.0  , 50  , 0.001
# Value, N observations, frequency : 700.0  , 14  , 0.0
# Value, N observations, frequency : 3568.0  , 2  , 0.0
# Value, N observations, frequency : 2608.0  , 2  , 0.0
# Value, N observations, frequency : 2991.0  , 2  , 0.0
# Value, N observations, frequency : 2989.0  , 2  , 0.0
# Value, N observations, frequency : 2998.0  , 2  , 0.0
# Value, N observations, frequency : 540.0  , 6  , 0.0
# Value, N observations, frequency : 2994.0  , 2  , 0.0
# Value, N observations, frequency : 400.0  , 14  , 0.0
# Value, N observations, frequency : 3130.0  , 6  , 0.0
# Value, N observations, frequency : 58.0  , 16  , 0.0
# Value, N observations, frequency : 1150.0  , 4  , 0.0
# Value, N observations, frequency : 55.0  , 30  , 0.001
# Value, N observations, frequency : 85.0  , 9  , 0.0
# Value, N observations, frequency : 4000.0  , 6  , 0.0
# Value, N observations, frequency : 2200.0  , 2  , 0.0
# Value, N observations, frequency : 180.0  , 31  , 0.001
# Value, N observations, frequency : 370.0  , 6  , 0.0
# Value, N observations, frequency : 4200.0  , 24  , 0.0
# Value, N observations, frequency : 2.0  , 689  , 0.012
# Value, N observations, frequency : 2204.0  , 2  , 0.0
# Value, N observations, frequency : 12.0  , 107  , 0.002
# Value, N observations, frequency : 7340.0  , 2  , 0.0
# Value, N observations, frequency : 260.0  , 12  , 0.0
# Value, N observations, frequency : 6200.0  , 2  , 0.0
# Value, N observations, frequency : 59.0  , 12  , 0.0
# Value, N observations, frequency : 870.0  , 2  , 0.0
# Value, N observations, frequency : 2300.0  , 2  , 0.0
# Value, N observations, frequency : 138.0  , 4  , 0.0
# Value, N observations, frequency : 3465.0  , 16  , 0.0
# Value, N observations, frequency : 13.0  , 78  , 0.001
# Value, N observations, frequency : 92.0  , 10  , 0.0
# Value, N observations, frequency : 170.0  , 31  , 0.001
# Value, N observations, frequency : 3350.0  , 2  , 0.0
# Value, N observations, frequency : 72.0  , 60  , 0.001
# Value, N observations, frequency : 4.0  , 334  , 0.006
# Value, N observations, frequency : 339.0  , 4  , 0.0
# Value, N observations, frequency : 250.0  , 24  , 0.0
# Value, N observations, frequency : 3450.0  , 2  , 0.0
# Value, N observations, frequency : 70.0  , 76  , 0.001
# Value, N observations, frequency : 340.0  , 4  , 0.0
# Value, N observations, frequency : 93.0  , 2  , 0.0
# Value, N observations, frequency : 227.0  , 2  , 0.0
# Value, N observations, frequency : 4299.0  , 2  , 0.0
# Value, N observations, frequency : 920.0  , 2  , 0.0
# Value, N observations, frequency : -1.0  , 20  , 0.0
# Value, N observations, frequency : 12200.0  , 2  , 0.0
# Value, N observations, frequency : 51.0  , 30  , 0.001
# Value, N observations, frequency : 9200.0  , 2  , 0.0
# Value, N observations, frequency : 210.0  , 56  , 0.001
# Value, N observations, frequency : 186.0  , 2  , 0.0
# Value, N observations, frequency : 152.0  , 12  , 0.0
# Value, N observations, frequency : 2099.0  , 2  , 0.0
# Value, N observations, frequency : 246.0  , 4  , 0.0
# Value, N observations, frequency : 81.0  , 8  , 0.0
# Value, N observations, frequency : 4500.0  , 2  , 0.0
# Value, N observations, frequency : 9.0  , 102  , 0.002
# Value, N observations, frequency : 191.0  , 4  , 0.0
# Value, N observations, frequency : 4199.0  , 2  , 0.0
# Value, N observations, frequency : 42.0  , 38  , 0.001
# Value, N observations, frequency : 330.0  , 6  , 0.0
# Value, N observations, frequency : 192.0  , 122  , 0.002
# Value, N observations, frequency : 4800.0  , 2  , 0.0
# Value, N observations, frequency : 605.0  , 2  , 0.0
# Value, N observations, frequency : 752.0  , 2  , 0.0
# Value, N observations, frequency : 199.0  , 4  , 0.0
# Value, N observations, frequency : 278.0  , 2  , 0.0
# Value, N observations, frequency : 2100.0  , 2  , 0.0
# Value, N observations, frequency : 420.0  , 30  , 0.001
# Value, N observations, frequency : 238.0  , 2  , 0.0
# Value, N observations, frequency : 206.0  , 4  , 0.0
# Value, N observations, frequency : 470.0  , 2  , 0.0
# Value, N observations, frequency : 384.0  , 88  , 0.001
# Value, N observations, frequency : 288.0  , 84  , 0.001
# Value, N observations, frequency : 52.0  , 26  , 0.0
# Value, N observations, frequency : 576.0  , 86  , 0.001
# Value, N observations, frequency : 672.0  , 40  , 0.001
# Value, N observations, frequency : 383.0  , 4  , 0.0
# Value, N observations, frequency : 64.0  , 26  , 0.0
# Value, N observations, frequency : 74.0  , 12  , 0.0
# Value, N observations, frequency : 632.0  , 2  , 0.0
# Value, N observations, frequency : 128.0  , 54  , 0.001
# Value, N observations, frequency : 66.0  , 14  , 0.0
# Value, N observations, frequency : 76.0  , 10  , 0.0
# Value, N observations, frequency : 103.0  , 2  , 0.0
# Value, N observations, frequency : 124.0  , 2  , 0.0
# Value, N observations, frequency : 118.0  , 4  , 0.0
# Value, N observations, frequency : 136.0  , 9  , 0.0
# Value, N observations, frequency : 87.0  , 4  , 0.0
# Value, N observations, frequency : 142.0  , 11  , 0.0
# Value, N observations, frequency : 95.0  , 4  , 0.0
# Value, N observations, frequency : 101.0  , 4  , 0.0
# Value, N observations, frequency : 105.0  , 10  , 0.0
# Value, N observations, frequency : 443.0  , 4  , 0.0
# Value, N observations, frequency : 580.0  , 6  , 0.0
# Value, N observations, frequency : 114.0  , 4  , 0.0
# Value, N observations, frequency : 131.0  , 8  , 0.0
# Value, N observations, frequency : 107.0  , 2  , 0.0
# Value, N observations, frequency : 69.0  , 6  , 0.0
# Value, N observations, frequency : 492.0  , 4  , 0.0
# Value, N observations, frequency : 780.0  , 6  , 0.0
# Value, N observations, frequency : 61.0  , 16  , 0.0
# Value, N observations, frequency : 372.0  , 8  , 0.0
# Value, N observations, frequency : 696.0  , 6  , 0.0
# Value, N observations, frequency : 140.0  , 24  , 0.0
# Value, N observations, frequency : 720.0  , 12  , 0.0
# Value, N observations, frequency : 91.0  , 6  , 0.0
# Value, N observations, frequency : 732.0  , 2  , 0.0
# Value, N observations, frequency : 130.0  , 40  , 0.001
# Value, N observations, frequency : 648.0  , 2  , 0.0
# Value, N observations, frequency : 828.0  , 2  , 0.0
# Value, N observations, frequency : 171.0  , 2  , 0.0
# Value, N observations, frequency : 600.0  , 14  , 0.0
# Value, N observations, frequency : 106.0  , 8  , 0.0
# Value, N observations, frequency : 840.0  , 6  , 0.0
# Value, N observations, frequency : 135.0  , 5  , 0.0
# Value, N observations, frequency : 900.0  , 8  , 0.0
# Value, N observations, frequency : 708.0  , 2  , 0.0
# Value, N observations, frequency : 143.0  , 2  , 0.0
# Value, N observations, frequency : 912.0  , 6  , 0.0
# Value, N observations, frequency : 111.0  , 6  , 0.0
# Value, N observations, frequency : 768.0  , 30  , 0.001
# Value, N observations, frequency : 86.0  , 10  , 0.0
# Value, N observations, frequency : 984.0  , 6  , 0.0
# Value, N observations, frequency : 960.0  , 16  , 0.0
# Value, N observations, frequency : 792.0  , 2  , 0.0
# Value, N observations, frequency : 744.0  , 4  , 0.0
# Value, N observations, frequency : 888.0  , 4  , 0.0
# Value, N observations, frequency : 936.0  , 4  , 0.0
# Value, N observations, frequency : 89.0  , 6  , 0.0
# Value, N observations, frequency : 1080.0  , 10  , 0.0
# Value, N observations, frequency : 945.0  , 2  , 0.0
# Value, N observations, frequency : 1260.0  , 16  , 0.0
# Value, N observations, frequency : 630.0  , 8  , 0.0
# Value, N observations, frequency : 83.0  , 4  , 0.0
# Value, N observations, frequency : 875.0  , 2  , 0.0
# Value, N observations, frequency : 1165.0  , 2  , 0.0
# Value, N observations, frequency : 47.0  , 23  , 0.0
# Value, N observations, frequency : 1096.0  , 2  , 0.0
# Value, N observations, frequency : 980.0  , 4  , 0.0
# Value, N observations, frequency : 1340.0  , 4  , 0.0
# Value, N observations, frequency : 112.0  , 14  , 0.0
# Value, N observations, frequency : 1360.0  , 4  , 0.0
# Value, N observations, frequency : 1200.0  , 6  , 0.0
# Value, N observations, frequency : 94.0  , 4  , 0.0
# Value, N observations, frequency : 168.0  , 22  , 0.0
# Value, N observations, frequency : 1420.0  , 2  , 0.0
# Value, N observations, frequency : 1580.0  , 2  , 0.0
# Value, N observations, frequency : 99.0  , 8  , 0.0
# Value, N observations, frequency : 1531.0  , 2  , 0.0
# Value, N observations, frequency : 127.0  , 4  , 0.0
# Value, N observations, frequency : 1060.0  , 2  , 0.0
# Value, N observations, frequency : 97.0  , 4  , 0.0
# Value, N observations, frequency : 1100.0  , 2  , 0.0
# Value, N observations, frequency : 147.0  , 4  , 0.0
# Value, N observations, frequency : 1440.0  , 6  , 0.0
# Value, N observations, frequency : 113.0  , 3  , 0.0
# Value, N observations, frequency : 1280.0  , 2  , 0.0
# Value, N observations, frequency : 78.0  , 16  , 0.0
# Value, N observations, frequency : 1190.0  , 2  , 0.0
# Value, N observations, frequency : 116.0  , 4  , 0.0
# Value, N observations, frequency : 1390.0  , 2  , 0.0
# Value, N observations, frequency : 126.0  , 4  , 0.0
# Value, N observations, frequency : 550.0  , 8  , 0.0
# Value, N observations, frequency : 96.0  , 48  , 0.001
# Value, N observations, frequency : 530.0  , 2  , 0.0
# Value, N observations, frequency : 211.0  , 6  , 0.0
# Value, N observations, frequency : 98.0  , 4  , 0.0
# Value, N observations, frequency : 144.0  , 34  , 0.001
# Value, N observations, frequency : 190.0  , 29  , 0.0
# Value, N observations, frequency : 251.0  , 2  , 0.0
# Value, N observations, frequency : 224.0  , 26  , 0.0
# Value, N observations, frequency : 671.0  , 6  , 0.0
# Value, N observations, frequency : 575.0  , 6  , 0.0
# Value, N observations, frequency : 864.0  , 8  , 0.0
# Value, N observations, frequency : 331.0  , 2  , 0.0
# Value, N observations, frequency : 640.0  , 4  , 0.0
# Value, N observations, frequency : 704.0  , 4  , 0.0
# Value, N observations, frequency : 790.0  , 2  , 0.0
# Value, N observations, frequency : 767.0  , 4  , 0.0
# Value, N observations, frequency : 863.0  , 2  , 0.0
# Value, N observations, frequency : 958.0  , 2  , 0.0
# Value, N observations, frequency : 1152.0  , 16  , 0.0
# Value, N observations, frequency : 959.0  , 2  , 0.0
# Value, N observations, frequency : 1754.0  , 2  , 0.0
# Value, N observations, frequency : 139.0  , 2  , 0.0
# Value, N observations, frequency : 1172.0  , 2  , 0.0
# Value, N observations, frequency : 182.0  , 4  , 0.0
# Value, N observations, frequency : 1812.0  , 2  , 0.0
# Value, N observations, frequency : 1398.0  , 2  , 0.0
# Value, N observations, frequency : 178.0  , 4  , 0.0
# Value, N observations, frequency : 1644.0  , 2  , 0.0
# Value, N observations, frequency : 1336.0  , 2  , 0.0
# Value, N observations, frequency : 208.0  , 12  , 0.0
# Value, N observations, frequency : 1590.0  , 4  , 0.0
# Value, N observations, frequency : 219.0  , 2  , 0.0
# Value, N observations, frequency : 1836.0  , 2  , 0.0
# Value, N observations, frequency : 1210.0  , 6  , 0.0
# Value, N observations, frequency : 327.0  , 2  , 0.0
# Value, N observations, frequency : 1902.0  , 2  , 0.0
# Value, N observations, frequency : 253.0  , 2  , 0.0
# Value, N observations, frequency : 1408.0  , 2  , 0.0
# Value, N observations, frequency : 275.0  , 6  , 0.0
# Value, N observations, frequency : 1479.0  , 2  , 0.0
# Value, N observations, frequency : 214.0  , 6  , 0.0
# Value, N observations, frequency : 2007.0  , 2  , 0.0
# Value, N observations, frequency : 308.0  , 2  , 0.0
# Value, N observations, frequency : 595.0  , 4  , 0.0
# Value, N observations, frequency : 848.0  , 2  , 0.0
# Value, N observations, frequency : 248.0  , 12  , 0.0
# Value, N observations, frequency : 1665.0  , 2  , 0.0
# Value, N observations, frequency : 258.0  , 2  , 0.0
# Value, N observations, frequency : 1464.0  , 2  , 0.0
# Value, N observations, frequency : 1014.0  , 2  , 0.0
# Value, N observations, frequency : 842.0  , 2  , 0.0
# Value, N observations, frequency : 334.0  , 2  , 0.0
# Value, N observations, frequency : 636.0  , 6  , 0.0
# Value, N observations, frequency : 1158.0  , 2  , 0.0
# Value, N observations, frequency : 1884.0  , 4  , 0.0
# Value, N observations, frequency : 244.0  , 2  , 0.0
# Value, N observations, frequency : 216.0  , 16  , 0.0
# Value, N observations, frequency : 2172.0  , 2  , 0.0
# Value, N observations, frequency : 2310.0  , 2  , 0.0
# Value, N observations, frequency : 284.0  , 2  , 0.0
# Value, N observations, frequency : 2304.0  , 4  , 0.0
# Value, N observations, frequency : 4461.0  , 2  , 0.0
# Value, N observations, frequency : 2229.0  , 2  , 0.0
# Value, N observations, frequency : 2578.0  , 2  , 0.0
# Value, N observations, frequency : 88.0  , 28  , 0.0
# Value, N observations, frequency : 2571.0  , 2  , 0.0
# Value, N observations, frequency : 2591.0  , 2  , 0.0
# Value, N observations, frequency : 104.0  , 20  , 0.0
# Value, N observations, frequency : 2592.0  , 6  , 0.0
# Value, N observations, frequency : 2014.0  , 2  , 0.0
# Value, N observations, frequency : 3167.0  , 2  , 0.0
# Value, N observations, frequency : 2880.0  , 6  , 0.0
# Value, N observations, frequency : 204.0  , 10  , 0.0
# Value, N observations, frequency : 4320.0  , 2  , 0.0
# Value, N observations, frequency : 3168.0  , 4  , 0.0
# Value, N observations, frequency : 169.0  , 2  , 0.0
# Value, N observations, frequency : 231.0  , 4  , 0.0
# Value, N observations, frequency : 230.0  , 20  , 0.0
# Value, N observations, frequency : 3744.0  , 4  , 0.0
# Value, N observations, frequency : 145.0  , 12  , 0.0
# Value, N observations, frequency : 3960.0  , 2  , 0.0
# Value, N observations, frequency : 174.0  , 5  , 0.0
# Value, N observations, frequency : 175.0  , 6  , 0.0
# Value, N observations, frequency : 2835.0  , 6  , 0.0
# Value, N observations, frequency : 3150.0  , 4  , 0.0
# Value, N observations, frequency : 3780.0  , 4  , 0.0
# Value, N observations, frequency : 4095.0  , 2  , 0.0
# Value, N observations, frequency : 3148.0  , 2  , 0.0
# Value, N observations, frequency : 245.0  , 2  , 0.0
# Value, N observations, frequency : 290.0  , 10  , 0.0
# Value, N observations, frequency : 3300.0  , 6  , 0.0
# Value, N observations, frequency : 165.0  , 4  , 0.0
# Value, N observations, frequency : 3900.0  , 2  , 0.0
# Value, N observations, frequency : 125.0  , 2  , 0.0
# Value, N observations, frequency : 3600.0  , 2  , 0.0
# Value, N observations, frequency : 2999.0  , 2  , 0.0
# Value, N observations, frequency : 1140.0  , 2  , 0.0
# Value, N observations, frequency : 1350.0  , 2  , 0.0
# Value, N observations, frequency : 729.0  , 2  , 0.0
# Value, N observations, frequency : 380.0  , 4  , 0.0
# Value, N observations, frequency : 115.0  , 2  , 0.0
# Value, N observations, frequency : 1120.0  , 2  , 0.0
# Value, N observations, frequency : 750.0  , 2  , 0.0
# Value, N observations, frequency : 1050.0  , 6  , 0.0
# Value, N observations, frequency : 368.0  , 4  , 0.0
# Value, N observations, frequency : 519.0  , 2  , 0.0
# Value, N observations, frequency : 440.0  , 4  , 0.0
# Value, N observations, frequency : 2208.0  , 2  , 0.0
# Value, N observations, frequency : 638.0  , 2  , 0.0
# Value, N observations, frequency : 446.0  , 2  , 0.0
# Value, N observations, frequency : 422.0  , 4  , 0.0
# Value, N observations, frequency : 467.0  , 2  , 0.0
# Value, N observations, frequency : 187.0  , 2  , 0.0
# Value, N observations, frequency : 353.0  , 2  , 0.0
# Value, N observations, frequency : 185.0  , 2  , 0.0
# Value, N observations, frequency : 624.0  , 2  , 0.0
# Value, N observations, frequency : 914.0  , 2  , 0.0
# Value, N observations, frequency : 1221.0  , 2  , 0.0
# Value, N observations, frequency : 713.0  , 2  , 0.0
# Value, N observations, frequency : 1154.0  , 2  , 0.0
# Value, N observations, frequency : 994.0  , 2  , 0.0
# Value, N observations, frequency : 1008.0  , 6  , 0.0
# Value, N observations, frequency : 3552.0  , 2  , 0.0
# Value, N observations, frequency : 1290.0  , 2  , 0.0
# Value, N observations, frequency : 1296.0  , 2  , 0.0
# Value, N observations, frequency : 1575.0  , 2  , 0.0
# Value, N observations, frequency : 1470.0  , 12  , 0.0
# Value, N observations, frequency : 1570.0  , 4  , 0.0
# Value, N observations, frequency : 1680.0  , 6  , 0.0
# Value, N observations, frequency : 1630.0  , 4  , 0.0
# Value, N observations, frequency : 62.0  , 9  , 0.0
# Value, N observations, frequency : 1840.0  , 2  , 0.0
# Value, N observations, frequency : 1230.0  , 2  , 0.0
# Value, N observations, frequency : 1450.0  , 2  , 0.0
# Value, N observations, frequency : 1790.0  , 2  , 0.0
# Value, N observations, frequency : 880.0  , 2  , 0.0
# Value, N observations, frequency : 520.0  , 6  , 0.0
# Value, N observations, frequency : 499.0  , 2  , 0.0
# Value, N observations, frequency : 484.0  , 2  , 0.0
# Value, N observations, frequency : 432.0  , 16  , 0.0
# Value, N observations, frequency : 554.0  , 2  , 0.0
# Value, N observations, frequency : 1234.0  , 2  , 0.0
# Value, N observations, frequency : 287.0  , 2  , 0.0
# Value, N observations, frequency : 1056.0  , 2  , 0.0
# Value, N observations, frequency : 3334.0  , 2  , 0.0
# Value, N observations, frequency : 1344.0  , 4  , 0.0
# Value, N observations, frequency : 567.0  , 2  , 0.0
# Value, N observations, frequency : 1068.0  , 2  , 0.0
# Value, N observations, frequency : 618.0  , 2  , 0.0
# Value, N observations, frequency : 212.0  , 4  , 0.0
# Value, N observations, frequency : 198.0  , 2  , 0.0
# Value, N observations, frequency : 820.0  , 2  , 0.0
# Value, N observations, frequency : 590.0  , 4  , 0.0
# Value, N observations, frequency : 132.0  , 18  , 0.0
# Value, N observations, frequency : 1083.0  , 2  , 0.0
# Value, N observations, frequency : 837.0  , 2  , 0.0
# Value, N observations, frequency : 1058.0  , 2  , 0.0
# Value, N observations, frequency : 1012.0  , 2  , 0.0
# Value, N observations, frequency : 830.0  , 4  , 0.0
# Value, N observations, frequency : 1236.0  , 2  , 0.0
# Value, N observations, frequency : 1128.0  , 2  , 0.0
# Value, N observations, frequency : 1248.0  , 2  , 0.0
# Value, N observations, frequency : 1392.0  , 2  , 0.0
# Value, N observations, frequency : 1320.0  , 2  , 0.0
# Value, N observations, frequency : 1608.0  , 2  , 0.0
# ...
# Value, N observations, frequency : 121487,09  , 1  , 0.0
# Value, N observations, frequency : 71216,57  , 1  , 0.0
# Value, N observations, frequency : 1240028  , 1  , 0.0
# Value, N observations, frequency : 134054,72  , 1  , 0.0
# Value, N observations, frequency : 491802,88  , 2  , 0.0
# Value, N observations, frequency : 62838,15  , 1  , 0.0
# Value, N observations, frequency : 1186326  , 1  , 0.0
# Value, N observations, frequency : 568647,08  , 1  , 0.0
# Value, N observations, frequency : 593045,13  , 1  , 0.0
# Value, N observations, frequency : 457030,91  , 2  , 0.0
# Value, N observations, frequency : 102112,25  , 1  , 0.0
# Value, N observations, frequency : 269723,16  , 1  , 0.0
# Value, N observations, frequency : 247246,23  , 1  , 0.0
# Value, N observations, frequency : 1200972  , 1  , 0.0
# Value, N observations, frequency : 1101369,57  , 1  , 0.0
# Value, N observations, frequency : 3192828  , 1  , 0.0
# Value, N observations, frequency : 284707,78  , 1  , 0.0
# Value, N observations, frequency : 2929200  , 1  , 0.0
# Value, N observations, frequency : 98027,52  , 1  , 0.0
# Value, N observations, frequency : 442046,29  , 1  , 0.0
# Value, N observations, frequency : 110698,86  , 1  , 0.0
# Value, N observations, frequency : 47788,44  , 2  , 0.0
# Value, N observations, frequency : 19911,85  , 6  , 0.0
# Value, N observations, frequency : 1435308  , 1  , 0.0
# Value, N observations, frequency : 3185673,9  , 1  , 0.0
# Value, N observations, frequency : 195736  , 1  , 0.0
# Value, N observations, frequency : 2010841,56  , 1  , 0.0
# Value, N observations, frequency : 2113961,64  , 1  , 0.0
# Value, N observations, frequency : 1988744,4  , 1  , 0.0
# Value, N observations, frequency : 1889307,18  , 1  , 0.0
# Value, N observations, frequency : 2025573  , 2  , 0.0
# Value, N observations, frequency : 2253910,32  , 1  , 0.0
# Value, N observations, frequency : 11648,4  , 5  , 0.0
# Value, N observations, frequency : 2357030,4  , 1  , 0.0
# Value, N observations, frequency : 336030  , 2  , 0.0
# Value, N observations, frequency : 1008090  , 1  , 0.0
# Value, N observations, frequency : 2062401,6  , 1  , 0.0
# Value, N observations, frequency : 2614830,6  , 1  , 0.0
# Value, N observations, frequency : 7765,6  , 1  , 0.0
# Value, N observations, frequency : 2430687,6  , 1  , 0.0
# Value, N observations, frequency : 2675598,6  , 1  , 0.0
# Value, N observations, frequency : 1867210,8  , 1  , 0.0
# Value, N observations, frequency : 11357,22  , 3  , 0.0
# Value, N observations, frequency : 1841500  , 2  , 0.0
# Value, N observations, frequency : 2872740  , 1  , 0.0
# Value, N observations, frequency : 401775  , 1  , 0.0
# Value, N observations, frequency : 2301875  , 1  , 0.0
# Value, N observations, frequency : 2110359  , 1  , 0.0
# Value, N observations, frequency : 22714,44  , 1  , 0.0
# Value, N observations, frequency : 2869057  , 1  , 0.0
# Value, N observations, frequency : 368300  , 1  , 0.0
# Value, N observations, frequency : 1436370  , 1  , 0.0
# Value, N observations, frequency : 317484,58  , 2  , 0.0
# Value, N observations, frequency : 11073,3  , 3  , 0.0
# Value, N observations, frequency : 2894838  , 1  , 0.0
# Value, N observations, frequency : 1845183  , 1  , 0.0
# Value, N observations, frequency : 977534,08  , 1  , 0.0
# Value, N observations, frequency : 841698,8  , 1  , 0.0
# Value, N observations, frequency : 643392,8  , 4  , 0.0
# Value, N observations, frequency : 1317633,2  , 1  , 0.0
# Value, N observations, frequency : 1288989  , 4  , 0.0
# Value, N observations, frequency : 533222,8  , 1  , 0.0
# Value, N observations, frequency : 1132547,6  , 1  , 0.0
# Value, N observations, frequency : 951868,8  , 5  , 0.0
# Value, N observations, frequency : -32334,2  , 1  , 0.0
# Value, N observations, frequency : 1163395,2  , 2  , 0.0
# Value, N observations, frequency : 415292,35  , 1  , 0.0
# Value, N observations, frequency : 362547,16  , 1  , 0.0
# Value, N observations, frequency : 267969,64  , 1  , 0.0
# Value, N observations, frequency : 1246022,7  , 1  , 0.0
# Value, N observations, frequency : 189155,04  , 1  , 0.0
# Value, N observations, frequency : 299495,48  , 1  , 0.0
# Value, N observations, frequency : 386979,56  , 1  , 0.0
# Value, N observations, frequency : 1126576,8  , 1  , 0.0
# Value, N observations, frequency : 1206494,4  , 1  , 0.0
# Value, N observations, frequency : 603246,24  , 1  , 0.0
# Value, N observations, frequency : 569732,56  , 1  , 0.0
# Value, N observations, frequency : 403765,44  , 1  , 0.0
# Value, N observations, frequency : 506894,41  , 1  , 0.0
# Value, N observations, frequency : 670320  , 1  , 0.0
# Value, N observations, frequency : 611624,66  , 1  , 0.0
# Value, N observations, frequency : 361167,74  , 1  , 0.0
# Value, N observations, frequency : 536256  , 1  , 0.0
# Value, N observations, frequency : 599384,76  , 1  , 0.0
# Value, N observations, frequency : 268128  , 1  , 0.0
# Value, N observations, frequency : 703008  , 8  , 0.0
# Value, N observations, frequency : 698126  , 1  , 0.0
# Value, N observations, frequency : 654188  , 1  , 0.0
# Value, N observations, frequency : 507171,72  , 1  , 0.0
# Value, N observations, frequency : 800648  , 1  , 0.0
# Value, N observations, frequency : 751344,19  , 1  , 0.0
# Value, N observations, frequency : 16337,96  , 1  , 0.0
# Value, N observations, frequency : 666815,59  , 1  , 0.0
# Value, N observations, frequency : 794184,86  , 1  , 0.0
# Value, N observations, frequency : 531954,01  , 1  , 0.0
# Value, N observations, frequency : 599384,8  , 1  , 0.0
# Value, N observations, frequency : 1718464  , 1  , 0.0
# Value, N observations, frequency : 1069158  , 1  , 0.0
# Value, N observations, frequency : 427061,67  , 1  , 0.0
# Value, N observations, frequency : 1048923,4  , 1  , 0.0
# Value, N observations, frequency : 664755  , 1  , 0.0
# Value, N observations, frequency : 1034984  , 1  , 0.0
# Value, N observations, frequency : 430995  , 1  , 0.0
# Value, N observations, frequency : 3982,37  , 1  , 0.0
# Value, N observations, frequency : 496740  , 1  , 0.0
# Value, N observations, frequency : 591705  , 1  , 0.0
# Value, N observations, frequency : 2080815,9  , 1  , 0.0
# Value, N observations, frequency : 642840  , 1  , 0.0
# Value, N observations, frequency : 3867003  , 1  , 0.0
# Value, N observations, frequency : 511350  , 1  , 0.0
# Value, N observations, frequency : 759720  , 1  , 0.0
# Value, N observations, frequency : 19414  , 5  , 0.0
# Value, N observations, frequency : 29292  , 3  , 0.0
# Value, N observations, frequency : 1712529,9  , 1  , 0.0
# Value, N observations, frequency : 533265  , 2  , 0.0
# Value, N observations, frequency : 577095  , 1  , 0.0
# Value, N observations, frequency : 2835802,2  , 1  , 0.0
# Value, N observations, frequency : 205788,4  , 1  , 0.0
# Value, N observations, frequency : 1124970  , 1  , 0.0
# Value, N observations, frequency : 2513553  , 1  , 0.0
# Value, N observations, frequency : 37857,4  , 1  , 0.0
# Value, N observations, frequency : 968629  , 1  , 0.0
# Value, N observations, frequency : 348306,63  , 1  , 0.0
# Value, N observations, frequency : 555180  , 1  , 0.0
# Value, N observations, frequency : 18928,7  , 3  , 0.0
# Value, N observations, frequency : 12205  , 1  , 0.0
# Value, N observations, frequency : 1424475  , 1  , 0.0
# Value, N observations, frequency : 40602,1  , 1  , 0.0
# Value, N observations, frequency : 56143  , 1  , 0.0
# Value, N observations, frequency : 3038475  , 1  , 0.0
# Value, N observations, frequency : 1712595  , 1  , 0.0
# Value, N observations, frequency : 42545  , 1  , 0.0
# Value, N observations, frequency : 854919,2  , 1  , 0.0
# Value, N observations, frequency : 625765,6  , 1  , 0.0
# Value, N observations, frequency : 713901,6  , 1  , 0.0
# Value, N observations, frequency : 757969,6  , 1  , 0.0
# Value, N observations, frequency : 555256,8  , 1  , 0.0
# Value, N observations, frequency : 1172208,8  , 1  , 0.0
# Value, N observations, frequency : 475934,4  , 1  , 0.0
# Value, N observations, frequency : 978309,6  , 1  , 0.0
# Value, N observations, frequency : 863732,8  , 1  , 0.0
# Value, N observations, frequency : 1017970,8  , 1  , 0.0
# Value, N observations, frequency : 943055,2  , 1  , 0.0
# Value, N observations, frequency : 1304412,8  , 1  , 0.0
# Value, N observations, frequency : 929834,8  , 1  , 0.0
# Value, N observations, frequency : 1238310,8  , 1  , 0.0
# Value, N observations, frequency : 1185429,2  , 1  , 0.0
# Value, N observations, frequency : 898987,2  , 1  , 0.0
# Value, N observations, frequency : 4049849,2  , 1  , 0.0
# Value, N observations, frequency : 315258,45  , 1  , 0.0
# Value, N observations, frequency : 379926,85  , 1  , 0.0
# Value, N observations, frequency : 1295599,2  , 1  , 0.0
# Value, N observations, frequency : 319300,2  , 1  , 0.0
# Value, N observations, frequency : 1168683,36  , 1  , 0.0
# Value, N observations, frequency : 409835,92  , 3  , 0.0
# Value, N observations, frequency : 1589753,1  , 1  , 0.0
# Value, N observations, frequency : 893699,04  , 1  , 0.0
# Value, N observations, frequency : 788146  , 1  , 0.0
# Value, N observations, frequency : 1271802,48  , 1  , 0.0
# Value, N observations, frequency : 401954,46  , 1  , 0.0
# Value, N observations, frequency : 2028009,36  , 1  , 0.0
# Value, N observations, frequency : 1761618,3  , 1  , 0.0
# Value, N observations, frequency : 1254615,96  , 1  , 0.0
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  47604
#
#  PRIS :
# Value, N observations, frequency : 8464.22  , 1  , 0.0
# Value, N observations, frequency : 4406.8  , 582  , 0.01
# Value, N observations, frequency : 27074.62  , 279  , 0.005
# Value, N observations, frequency : 8083.55  , 358  , 0.006
# Value, N observations, frequency : 7982.5  , 2  , 0.0
# Value, N observations, frequency : 4296.63  , 143  , 0.002
# Value, N observations, frequency : 7881.46  , 124  , 0.002
# Value, N observations, frequency : 26397.75  , 88  , 0.001
# Value, N observations, frequency : 7782.94  , 2  , 0.0
# Value, N observations, frequency : 4225.02  , 2  , 0.0
# Value, N observations, frequency : 25946.21  , 1  , 0.0
# Value, N observations, frequency : 25994.45  , 1  , 0.0
# Value, N observations, frequency : 7684.42  , 246  , 0.004
# Value, N observations, frequency : 4189.22  , 12  , 0.0
# Value, N observations, frequency : 25737.81  , 222  , 0.004
# Value, N observations, frequency : 4189.21  , 210  , 0.004
# Value, N observations, frequency : 4205.89  , 16  , 0.0
# Value, N observations, frequency : 2793.0  , 34  , 0.001
# Value, N observations, frequency : 2622.95  , 1  , 0.0
# Value, N observations, frequency : 2441.0  , 368  , 0.006
# Value, N observations, frequency : 7631.06  , 1  , 0.0
# Value, N observations, frequency : 4136.85  , 1  , 0.0
# Value, N observations, frequency : 25308.84  , 2  , 0.0
# Value, N observations, frequency : 7492.31  , 91  , 0.002
# Value, N observations, frequency : 4084.49  , 8  , 0.0
# Value, N observations, frequency : 25094.36  , 310  , 0.005
# Value, N observations, frequency : 4084.48  , 71  , 0.001
# Value, N observations, frequency : 4050.44  , 1  , 0.0
# Value, N observations, frequency : 7355.62  , 1  , 0.0
# Value, N observations, frequency : 3982.37  , 93  , 0.002
# Value, N observations, frequency : 24467.0  , 135  , 0.002
# Value, N observations, frequency : 24676.12  , 1  , 0.0
# Value, N observations, frequency : 7305.0  , 371  , 0.006
# Value, N observations, frequency : 3682.86  , 170  , 0.003
# Value, N observations, frequency : 3932.58  , 1  , 0.0
# Value, N observations, frequency : 23855.33  , 125  , 0.002
# Value, N observations, frequency : 3882.8  , 78  , 0.001
# Value, N observations, frequency : 3785.74  , 72  , 0.001
# Value, N observations, frequency : 23258.95  , 134  , 0.002
# Value, N observations, frequency : 3683.0  , 91  , 0.002
# Value, N observations, frequency : 3590.79  , 19  , 0.0
# Value, N observations, frequency : 11049.0  , 82  , 0.001
# Value, N observations, frequency : 3691.1  , 52  , 0.001
# Value, N observations, frequency : 22677.47  , 102  , 0.002
# Value, N observations, frequency : 7977.69  , 1  , 0.0
# Value, N observations, frequency : 4232.18  , 1  , 0.0
# Value, N observations, frequency : 25815.45  , 1  , 0.0
# Value, N observations, frequency : 25857.8  , 1  , 0.0
# Value, N observations, frequency : 2657.62  , 1  , 0.0
# Value, N observations, frequency : 7627.5  , 1  , 0.0
# Value, N observations, frequency : 25163.92  , 1  , 0.0
# Value, N observations, frequency : 7413.98  , 1  , 0.0
# Value, N observations, frequency : 3919.38  , 1  , 0.0
# Value, N observations, frequency : 24051.06  , 1  , 0.0
# Value, N observations, frequency : 23925.91  , 1  , 0.0
# Value, N observations, frequency : 3618.58  , 1  , 0.0
# Value, N observations, frequency : 3832.1  , 1  , 0.0
# Value, N observations, frequency : 23528.74  , 1  , 0.0
# Value, N observations, frequency : 23408.04  , 1  , 0.0
# Value, N observations, frequency : 7948.82  , 2  , 0.0
# Value, N observations, frequency : 7776.78  , 1  , 0.0
# Value, N observations, frequency : 4237.62  , 1  , 0.0
# Value, N observations, frequency : 25957.79  , 2  , 0.0
# Value, N observations, frequency : 2685.38  , 1  , 0.0
# Value, N observations, frequency : 7620.38  , 3  , 0.0
# Value, N observations, frequency : 4099.45  , 1  , 0.0
# Value, N observations, frequency : 4061.79  , 2  , 0.0
# Value, N observations, frequency : 7392.56  , 1  , 0.0
# Value, N observations, frequency : 24623.84  , 1  , 0.0
# Value, N observations, frequency : 3621.48  , 1  , 0.0
# Value, N observations, frequency : 7768.87  , 1  , 0.0
# Value, N observations, frequency : 26104.44  , 1  , 0.0
# Value, N observations, frequency : 2687.4  , 1  , 0.0
# Value, N observations, frequency : 25630.57  , 1  , 0.0
# Value, N observations, frequency : 7382.51  , 1  , 0.0
# Value, N observations, frequency : 24702.26  , 1  , 0.0
# Value, N observations, frequency : 24613.38  , 1  , 0.0
# Value, N observations, frequency : 3957.48  , 1  , 0.0
# Value, N observations, frequency : 23912.67  , 1  , 0.0
# Value, N observations, frequency : 3606.14  , 2  , 0.0
# Value, N observations, frequency : 23497.5  , 1  , 0.0
# Value, N observations, frequency : 23434.36  , 1  , 0.0
# Value, N observations, frequency : 8509.0  , 2  , 0.0
# Value, N observations, frequency : 4210.7  , 1  , 0.0
# Value, N observations, frequency : 4103.53  , 1  , 0.0
# Value, N observations, frequency : 4067.46  , 1  , 0.0
# Value, N observations, frequency : 3612.45  , 1  , 0.0
# Value, N observations, frequency : 3812.21  , 1  , 0.0
# Value, N observations, frequency : 23609.76  , 1  , 0.0
# Value, N observations, frequency : 23530.03  , 1  , 0.0
# Value, N observations, frequency : 3703.72  , 1  , 0.0
# Value, N observations, frequency : 7926.37  , 1  , 0.0
# Value, N observations, frequency : 7802.64  , 1  , 0.0
# Value, N observations, frequency : 4253.67  , 1  , 0.0
# Value, N observations, frequency : 2652.2  , 1  , 0.0
# Value, N observations, frequency : 4108.29  , 1  , 0.0
# Value, N observations, frequency : 24263.11  , 1  , 0.0
# Value, N observations, frequency : 23557.14  , 1  , 0.0
# Value, N observations, frequency : 4267.71  , 1  , 0.0
# Value, N observations, frequency : 2608.62  , 1  , 0.0
# Value, N observations, frequency : 2630.54  , 1  , 0.0
# Value, N observations, frequency : 3619.12  , 1  , 0.0
# Value, N observations, frequency : 7962.3  , 1  , 0.0
# Value, N observations, frequency : 7835.64  , 1  , 0.0
# Value, N observations, frequency : 4242.92  , 1  , 0.0
# Value, N observations, frequency : 2640.78  , 1  , 0.0
# Value, N observations, frequency : 7599.04  , 1  , 0.0
# Value, N observations, frequency : 7405.86  , 1  , 0.0
# Value, N observations, frequency : 3615.34  , 1  , 0.0
# Value, N observations, frequency : 7912.55  , 1  , 0.0
# Value, N observations, frequency : 7756.07  , 1  , 0.0
# Value, N observations, frequency : 2621.09  , 1  , 0.0
# Value, N observations, frequency : 7603.14  , 1  , 0.0
# Value, N observations, frequency : 7379.92  , 1  , 0.0
# Value, N observations, frequency : 3615.67  , 1  , 0.0
# Value, N observations, frequency : 4363.99  , 1  , 0.0
# Value, N observations, frequency : 7986.39  , 1  , 0.0
# Value, N observations, frequency : 7739.59  , 1  , 0.0
# Value, N observations, frequency : 4267.34  , 1  , 0.0
# Value, N observations, frequency : 7589.34  , 1  , 0.0
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  54983

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59770 entries, 0 to 59769
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year Month           12166 non-null  float64
#  1   Region               12166 non-null  object
#  2   Account Description  12166 non-null  object
#  3   Product              12166 non-null  object
#  4   Company              4786 non-null   object
#  5   Size                 12166 non-null  object
#  6   Size Numeric         12166 non-null  float64
#  7   Strength             12166 non-null  object
#  8   WHO ATC 5 Code       12166 non-null  object
#  9   Volume               12166 non-null  float64
#  10  Value                12166 non-null  object
#  11  PRIS                 4787 non-null   float64
# dtypes: float64(4), object(8)
# memory usage: 5.5+ MB

# %%
df_dropped = df.dropna()
df_dropped
# Out:
#       Year Month       Region                       Account Description  \
# 0       201001.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 1       201001.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 2       201001.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 3       201002.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# 4       201002.0  Hovedstaden  4060 Centralapoteket, Region Hovedstaden
# ...          ...          ...                                       ...
# 4782    201310.0  Midtjylland             4398 Viborg Sygehus, apoteket
# 4783    201311.0  Midtjylland             4398 Viborg Sygehus, apoteket
# 4784    201311.0  Midtjylland             4398 Viborg Sygehus, apoteket
# 4785    201312.0  Midtjylland             4398 Viborg Sygehus, apoteket
# 4786    201312.0  Midtjylland             4398 Viborg Sygehus, apoteket
#
#        Product     Company              Size  Size Numeric      Strength  \
# 0       Cimzia  UCB Nordic            2 stk.           2.0        200 mg
# 1     Remicade         MSD  1 htgl. a 100 mg         100.0        100 mg
# 2      Stelara     Janssen             1 stk           1.0  45 mg/0,5 ml
# 3       Cimzia  UCB Nordic            2 stk.           2.0        200 mg
# 4     Remicade         MSD  1 htgl. a 100 mg         100.0        100 mg
# ...        ...         ...               ...           ...           ...
# 4782  Remicade         MSD           1 htgl.           1.0        100 mg
# 4783    Cimzia  UCB Nordic            2 stk.           2.0        200 mg
# 4784  Remicade         MSD           1 htgl.           1.0        100 mg
# 4785    Cimzia  UCB Nordic            2 stk.           2.0        200 mg
# 4786  Remicade         MSD           1 htgl.           1.0        100 mg
#
#      WHO ATC 5 Code  Volume       Value      PRIS
# 0           L04AB05    19.0    160820.1   8464.22
# 1           L04AB02  2096.0   9236652.8   4406.80
# 2           L04AC05    23.0   622716.26  27074.62
# 3           L04AB05    11.0    88919.05   8083.55
# 4           L04AB02  2036.0   8972244.8   4406.80
# ...             ...     ...         ...       ...
# 4782        L04AB02   472.0  2028009.36   4296.63
# 4783        L04AB05    45.0    354665.7   7881.46
# 4784        L04AB02   410.0   1761618.3   4296.63
# 4785        L04AB05    52.0   409835.92   7881.46
# 4786        L04AB02   292.0  1254615.96   4296.63
#
# [4786 rows x 12 columns]

# %% [markdown]
# OBS they might not need to be droped. Maybe one of the dataframes spell the brick differently, affecting the merge.

# %% [markdown]
# #### 2. Convert features with potential to be numeric into numeric features
# from the investigation of the features we can see that a number of features can be converted from object data types into integers or floats.

# %%
to_numeric = [
    'blood clot in heart', 
    'absence', 
    'life_expectancy_years', 
    'longterm_disease_andel',
    'overweight_andel',
    't2d_patients',
    'uddannelse_lang_amount'
]
for col in to_numeric:
    df_dropped[col] = df_dropped[col].str.replace(',', '.', regex=True).astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'blood clot in heart'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 11
#       1 to_numeric = [
#       2     'blood clot in heart',
#       3     'absence',
#    (...)
#       8     'uddannelse_lang_amount'
#       9 ]
#      10 for col in to_numeric:
# ---> 11     df_dropped[col] = df_dropped[col].str.replace(',', '.', regex=True).astype(float)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'blood clot in heart'

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76099 entries, 0 to 222794
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   brick_nr                76099 non-null  float64
#  1   brick                   76099 non-null  object
#  2   blood clot in heart     76099 non-null  float64
#  3   absence                 76099 non-null  float64
#  4   life_expectancy_years   76099 non-null  float64
#  5   longterm_disease_andel  76099 non-null  float64
#  6   overweight_andel        76099 non-null  float64
#  7   t2d_patients            76099 non-null  float64
#  8   uddannelse_lang_amount  76099 non-null  float64
#  9   physical_activity       76099 non-null  object
#  10  YEAR_MONTH              76099 non-null  float64
#  11  SECTOR_CODE             76099 non-null  object
#  12  VOLUME                  76099 non-null  float64
#  13  VALUE                   76099 non-null  float64
#  14  WHO_ATC_CODE            76099 non-null  object
# dtypes: float64(11), object(4)
# memory usage: 9.3+ MB

# %% [markdown]
# Another interesting column is the column of YEAR_MONTH.

# %%
df_dropped['YEAR_MONTH'].unique()
# Out:
# array([202009., 202008., 202007., 202102., 202005., 202101., 202010.,
#        202103., 202011., 202012., 202004., 202006.])

# %% [markdown]
# Looking at the column we can see that it combines both year and month into one as a float. Possible in the future it might be interesting to look at each year or each month. So lets split it and make it into two columns; one for year and one for month

# %%
# We start by making the column into a string to make it easier to slice
df_dropped['YEAR_MONTH'] = df_dropped['YEAR_MONTH'].astype(str)

# We then slice the year from the first 4 digits
df_dropped['year'] = df_dropped['YEAR_MONTH'].str[:4]  
# We then slice the year from the 4th digit to the 6th digit
df_dropped['month'] = df_dropped['YEAR_MONTH'].str[4:6]
df_dropped
# Out:
# C:\Users\nped\AppData\Local\Temp\ipykernel_24712\2133612125.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped['YEAR_MONTH'] = df_dropped['YEAR_MONTH'].astype(str)
# C:\Users\nped\AppData\Local\Temp\ipykernel_24712\2133612125.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped['year'] = df_dropped['YEAR_MONTH'].str[:4]
# C:\Users\nped\AppData\Local\Temp\ipykernel_24712\2133612125.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped['month'] = df_dropped['YEAR_MONTH'].str[4:6]
#         brick_nr        brick  blood clot in heart   absence  \
# 0          308.0     Aabenraa             0.013750  6.002000
# 1          308.0     Aabenraa             0.013750  6.002000
# 2          308.0     Aabenraa             0.013750  6.002000
# 3          308.0     Aabenraa             0.013750  6.002000
# 4          308.0     Aabenraa             0.013750  6.002000
# ...          ...          ...                  ...       ...
# 222790     207.0  Vordingborg             0.013833  6.345222
# 222791     207.0  Vordingborg             0.013833  6.345222
# 222792     207.0  Vordingborg             0.013833  6.345222
# 222793     207.0  Vordingborg             0.013833  6.345222
# 222794     207.0  Vordingborg             0.013833  6.345222
#
#         life_expectancy_years  longterm_disease_andel  overweight_andel  \
# 0                   80.925500                0.358000          0.206333
# 1                   80.925500                0.358000          0.206333
# 2                   80.925500                0.358000          0.206333
# 3                   80.925500                0.358000          0.206333
# 4                   80.925500                0.358000          0.206333
# ...                       ...                     ...               ...
# 222790              79.865444                0.379111          0.231143
# 222791              79.865444                0.379111          0.231143
# 222792              79.865444                0.379111          0.231143
# 222793              79.865444                0.379111          0.231143
# 222794              79.865444                0.379111          0.231143
#
#         t2d_patients  uddannelse_lang_amount    physical_activity YEAR_MONTH  \
# 0        3936.207344            11845.819974  0,33866666666666667   202009.0
# 1        3936.207344            11845.819974  0,33866666666666667   202008.0
# 2        3936.207344            11845.819974  0,33866666666666667   202008.0
# 3        3936.207344            11845.819974  0,33866666666666667   202008.0
# 4        3936.207344            11845.819974  0,33866666666666667   202009.0
# ...              ...                     ...                  ...        ...
# 222790   3873.451601            12043.591696                0,334   202007.0
# 222791   3873.451601            12043.591696                0,334   202007.0
# 222792   3873.451601            12043.591696                0,334   202009.0
# 222793   3873.451601            12043.591696                0,334   202010.0
# 222794   3873.451601            12043.591696                0,334   202012.0
#
#        SECTOR_CODE  VOLUME    VALUE WHO_ATC_CODE  year month
# 0                P    -1.0  -603.65      A10BH01  2020    09
# 1                P     1.0   238.08      A10AC01  2020    08
# 2                P    10.0  4894.70      A10AE06  2020    08
# 3                P     3.0   891.87      A10AD01  2020    08
# 4                P    25.0  6907.75      A10AC01  2020    09
# ...            ...     ...      ...          ...   ...   ...
# 222790           P     4.0  1266.88      A10BK03  2020    07
# 222791           P     0.0   -53.38      A10BD08  2020    07
# 222792           P   391.0  4301.00      A10BA02  2020    09
# 222793           P     1.0   278.88      A10BD08  2020    10
# 222794           P     3.0   981.30      A10BD20  2020    12
#
# [76099 rows x 17 columns]

# %% [markdown]
# #### 3. Another way to handle missing values
# if we go back to the dataset from before we dropped nan values.
#
# Here we can see that there are a number of missing values

# %%
df
# Out:
#         brick_nr       brick blood clot in heart absence  \
# 0          308.0    Aabenraa             0,01375   6,002
# 1          308.0    Aabenraa             0,01375   6,002
# 2          308.0    Aabenraa             0,01375   6,002
# 3          308.0    Aabenraa             0,01375   6,002
# 4          308.0    Aabenraa             0,01375   6,002
# ...          ...         ...                 ...     ...
# 223696       NaN       ÃrÃ¸                 NaN     NaN
# 223697       NaN       ÃrÃ¸                 NaN     NaN
# 223698       NaN       ÃrÃ¸                 NaN     NaN
# 223699       NaN       ÃrÃ¸                 NaN     NaN
# 223700     403.0  Århus City               0,009    5,28
#
#        life_expectancy_years longterm_disease_andel     overweight_andel  \
# 0                    80,9255                  0,358  0,20633333333333334
# 1                    80,9255                  0,358  0,20633333333333334
# 2                    80,9255                  0,358  0,20633333333333334
# 3                    80,9255                  0,358  0,20633333333333334
# 4                    80,9255                  0,358  0,20633333333333334
# ...                      ...                    ...                  ...
# 223696                   NaN                    NaN                  NaN
# 223697                   NaN                    NaN                  NaN
# 223698                   NaN                    NaN                  NaN
# 223699                   NaN                    NaN                  NaN
# 223700                  81,5                  0,316                 0,11
#
#        t2d_patients uddannelse_lang_amount    physical_activity  YEAR_MONTH  \
# 0       3936,207344     11845,819973539024  0,33866666666666667    202009.0
# 1       3936,207344     11845,819973539024  0,33866666666666667    202008.0
# 2       3936,207344     11845,819973539024  0,33866666666666667    202008.0
# 3       3936,207344     11845,819973539024  0,33866666666666667    202008.0
# 4       3936,207344     11845,819973539024  0,33866666666666667    202009.0
# ...             ...                    ...                  ...         ...
# 223696          NaN                    NaN                  NaN    202006.0
# 223697          NaN                    NaN                  NaN    202007.0
# 223698          NaN                    NaN                  NaN    202008.0
# 223699          NaN                    NaN                  NaN    202011.0
# 223700   2169,52533     23503,461421150456                 0,24         NaN
#
#        SECTOR_CODE  VOLUME    VALUE WHO_ATC_CODE
# 0                P    -1.0  -603.65      A10BH01
# 1                P     1.0   238.08      A10AC01
# 2                P    10.0  4894.70      A10AE06
# 3                P     3.0   891.87      A10AD01
# 4                P    25.0  6907.75      A10AC01
# ...            ...     ...      ...          ...
# 223696           P     2.0   708.98      A10AB05
# 223697           P     3.0  3087.69      A10BK01
# 223698           P    -3.0 -3145.80      A10BK01
# 223699           P     1.0   622.85      A10BJ06
# 223700         NaN     NaN      NaN          NaN
#
# [223701 rows x 15 columns]

# %%
# Let's look at the number of Nans for each numeric column
cols = df.select_dtypes(include=['float64', 'int64','object']).columns

Nrows = df.shape[0]
# Go through each column except for the ones we want to drop
for col in cols:
    # get unique values in column
    unique = df[col].unique();
    print(col,":")
    print("No. of NANs ", len(df[df[col].isna()]))
# Out:
# brick_nr :
# No. of NANs  147574
# brick :
# No. of NANs  0
# blood clot in heart :
# No. of NANs  147574
# absence :
# No. of NANs  147574
# life_expectancy_years :
# No. of NANs  147574
# longterm_disease_andel :
# No. of NANs  147574
# overweight_andel :
# No. of NANs  147574
# t2d_patients :
# No. of NANs  147574
# uddannelse_lang_amount :
# No. of NANs  147574
# physical_activity :
# No. of NANs  147574
# YEAR_MONTH :
# No. of NANs  28
# SECTOR_CODE :
# No. of NANs  28
# VOLUME :
# No. of NANs  28
# VALUE :
# No. of NANs  28
# WHO_ATC_CODE :
# No. of NANs  28

# %% [markdown]
# Here we see that there are a number of missing values. Some of these can be handled through the merging between the dataframe SALES.csv and others.

# %% [markdown]
# Because of this we are not gonna focus on those values. But what about 'volume' and 'value'. Both columns are from the SALES dataset and are both contain float values. As such we are able to use a imputer to fill the missing value.
#
# This method allows us to make a predictive model that predicts the missing values.

# %%
# Imputation functions
from sklearn.impute import KNNImputer, SimpleImputer

num_cols = ['VOLUME','VALUE']
# Too impute missing values, we introduce the following functions

# This imputer only simply replace the missing values with mean, median or most frequent value of that feature
simple_imputer = SimpleImputer(missing_values=np.nan, strategy='mean') 

# This imputer considers all numeric features and assigns to each missing value the feature mean of the n nearest neighbors
knn_imputer = KNNImputer(missing_values = np.nan, n_neighbors = 5)

# We will use the knn imputer, since it considers all numeric features to find the most similar neighbors:
df.loc[:, num_cols] = knn_imputer.fit_transform(df.loc[:, num_cols] )
df
# Out:
#         brick_nr       brick blood clot in heart absence  \
# 0          308.0    Aabenraa             0,01375   6,002
# 1          308.0    Aabenraa             0,01375   6,002
# 2          308.0    Aabenraa             0,01375   6,002
# 3          308.0    Aabenraa             0,01375   6,002
# 4          308.0    Aabenraa             0,01375   6,002
# ...          ...         ...                 ...     ...
# 223696       NaN       ÃrÃ¸                 NaN     NaN
# 223697       NaN       ÃrÃ¸                 NaN     NaN
# 223698       NaN       ÃrÃ¸                 NaN     NaN
# 223699       NaN       ÃrÃ¸                 NaN     NaN
# 223700     403.0  Århus City               0,009    5,28
#
#        life_expectancy_years longterm_disease_andel     overweight_andel  \
# 0                    80,9255                  0,358  0,20633333333333334
# 1                    80,9255                  0,358  0,20633333333333334
# 2                    80,9255                  0,358  0,20633333333333334
# 3                    80,9255                  0,358  0,20633333333333334
# 4                    80,9255                  0,358  0,20633333333333334
# ...                      ...                    ...                  ...
# 223696                   NaN                    NaN                  NaN
# 223697                   NaN                    NaN                  NaN
# 223698                   NaN                    NaN                  NaN
# 223699                   NaN                    NaN                  NaN
# 223700                  81,5                  0,316                 0,11
#
#        t2d_patients uddannelse_lang_amount    physical_activity  YEAR_MONTH  \
# 0       3936,207344     11845,819973539024  0,33866666666666667    202009.0
# 1       3936,207344     11845,819973539024  0,33866666666666667    202008.0
# 2       3936,207344     11845,819973539024  0,33866666666666667    202008.0
# 3       3936,207344     11845,819973539024  0,33866666666666667    202008.0
# 4       3936,207344     11845,819973539024  0,33866666666666667    202009.0
# ...             ...                    ...                  ...         ...
# 223696          NaN                    NaN                  NaN    202006.0
# 223697          NaN                    NaN                  NaN    202007.0
# 223698          NaN                    NaN                  NaN    202008.0
# 223699          NaN                    NaN                  NaN    202011.0
# 223700   2169,52533     23503,461421150456                 0,24         NaN
#
#        SECTOR_CODE     VOLUME        VALUE WHO_ATC_CODE
# 0                P  -1.000000  -603.650000      A10BH01
# 1                P   1.000000   238.080000      A10AC01
# 2                P  10.000000  4894.700000      A10AE06
# 3                P   3.000000   891.870000      A10AD01
# 4                P  25.000000  6907.750000      A10AC01
# ...            ...        ...          ...          ...
# 223696           P   2.000000   708.980000      A10AB05
# 223697           P   3.000000  3087.690000      A10BK01
# 223698           P  -3.000000 -3145.800000      A10BK01
# 223699           P   1.000000   622.850000      A10BJ06
# 223700         NaN  16.634623  4946.722091          NaN
#
# [223701 rows x 15 columns]

# %% [markdown]
# Here an example is shown that a prediction is made of "16.63" for VOLUME, and "4946.722" for VALUE

# %% [markdown]
# #### 4. Convert categorical features to numeric ones
# - Convert features with two values to boolean features
# - Label encode features with order
# - One hot encoding

# %% [markdown]
# In our dataset we have the column SECTOR_CODE with *P* and *S*
# this represent XXX.

# %%
df_dropped['SECTOR_CODE'].unique()
# Out:
# array(['P', 'S'], dtype=object)

# %% [markdown]
# If we wish to utilise this function for predictive modelling then we would have to change it into a numeric representation.
# As there are only two different values it would be perfect to convert it into a boolean (0,1)

# %%
# First we describe the numeric representation
sector_code_rep = {'P': 0, 'S': 1}
df_dropped['SECTOR_CODE'] = df_dropped['SECTOR_CODE'].map(sector_code_rep)
df_dropped['SECTOR_CODE'].unique()
# Out:
# C:\Users\nped\AppData\Local\Temp\ipykernel_24712\1042394591.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped['SECTOR_CODE'] = df_dropped['SECTOR_CODE'].map(sector_code_rep)
# array([0, 1], dtype=int64)

# %%
df_dropped
# Out:
#         brick_nr        brick  blood clot in heart   absence  \
# 0          308.0     Aabenraa             0.013750  6.002000
# 1          308.0     Aabenraa             0.013750  6.002000
# 2          308.0     Aabenraa             0.013750  6.002000
# 3          308.0     Aabenraa             0.013750  6.002000
# 4          308.0     Aabenraa             0.013750  6.002000
# ...          ...          ...                  ...       ...
# 222790     207.0  Vordingborg             0.013833  6.345222
# 222791     207.0  Vordingborg             0.013833  6.345222
# 222792     207.0  Vordingborg             0.013833  6.345222
# 222793     207.0  Vordingborg             0.013833  6.345222
# 222794     207.0  Vordingborg             0.013833  6.345222
#
#         life_expectancy_years  longterm_disease_andel  overweight_andel  \
# 0                   80.925500                0.358000          0.206333
# 1                   80.925500                0.358000          0.206333
# 2                   80.925500                0.358000          0.206333
# 3                   80.925500                0.358000          0.206333
# 4                   80.925500                0.358000          0.206333
# ...                       ...                     ...               ...
# 222790              79.865444                0.379111          0.231143
# 222791              79.865444                0.379111          0.231143
# 222792              79.865444                0.379111          0.231143
# 222793              79.865444                0.379111          0.231143
# 222794              79.865444                0.379111          0.231143
#
#         t2d_patients  uddannelse_lang_amount    physical_activity YEAR_MONTH  \
# 0        3936.207344            11845.819974  0,33866666666666667   202009.0
# 1        3936.207344            11845.819974  0,33866666666666667   202008.0
# 2        3936.207344            11845.819974  0,33866666666666667   202008.0
# 3        3936.207344            11845.819974  0,33866666666666667   202008.0
# 4        3936.207344            11845.819974  0,33866666666666667   202009.0
# ...              ...                     ...                  ...        ...
# 222790   3873.451601            12043.591696                0,334   202007.0
# 222791   3873.451601            12043.591696                0,334   202007.0
# 222792   3873.451601            12043.591696                0,334   202009.0
# 222793   3873.451601            12043.591696                0,334   202010.0
# 222794   3873.451601            12043.591696                0,334   202012.0
#
#         SECTOR_CODE  VOLUME    VALUE WHO_ATC_CODE  year month
# 0                 0    -1.0  -603.65      A10BH01  2020    09
# 1                 0     1.0   238.08      A10AC01  2020    08
# 2                 0    10.0  4894.70      A10AE06  2020    08
# 3                 0     3.0   891.87      A10AD01  2020    08
# 4                 0    25.0  6907.75      A10AC01  2020    09
# ...             ...     ...      ...          ...   ...   ...
# 222790            0     4.0  1266.88      A10BK03  2020    07
# 222791            0     0.0   -53.38      A10BD08  2020    07
# 222792            0   391.0  4301.00      A10BA02  2020    09
# 222793            0     1.0   278.88      A10BD08  2020    10
# 222794            0     3.0   981.30      A10BD20  2020    12
#
# [76099 rows x 17 columns]

# %% [markdown]
# #### Ranking ordered features (ordinal features) using label encoding:
#
# Since one-hot encoding can increase the no. of features dramatically,
# we will show another method of changing categorical features into numeric - LabelEncoding. Import to note here is that if we just use LabelEncoding then the categorical feature will be label in order of frequency. However, when we utilise this feature for training machine learning models, it will count the ones with higher values as being more important. This is not necessarily the truth. We wish for a way so that the order of numbers is representative. Thus we need to make an order to base our labeling on. Sometimes, the order is very clear (e.g. low, mid, high, very high), and sometimes we have to be
# a bit creative.
#
#
# In the following, we'll convert the brick and brick_nr by finding a metric for the order and then using label encoding. Looking at the dataframe there are many different features that could be the basis for creating the order. Just as an example we will use the number of type 2 diabetes (t2d_patients)

# %%
from sklearn.preprocessing import LabelEncoder

# Sort the DataFrame based on column_y to define the order
encoded_df = df_dropped.sort_values(by='longterm_disease_andel')

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the sorted column_x and transform it
encoded_df['brick'] = label_encoder.fit_transform(encoded_df['brick'])

df_dropped['brick'] = encoded_df.set_index(df_dropped.index)['brick']
df_dropped
# Out:
# C:\Users\nped\AppData\Local\Temp\ipykernel_24712\1564712222.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped['brick'] = encoded_df.set_index(df_dropped.index)['brick']
#         brick_nr  brick  blood clot in heart   absence  life_expectancy_years  \
# 0          308.0      5             0.013750  6.002000              80.925500
# 1          308.0      5             0.013750  6.002000              80.925500
# 2          308.0      5             0.013750  6.002000              80.925500
# 3          308.0      5             0.013750  6.002000              80.925500
# 4          308.0      5             0.013750  6.002000              80.925500
# ...          ...    ...                  ...       ...                    ...
# 222790     207.0     17             0.013833  6.345222              79.865444
# 222791     207.0     17             0.013833  6.345222              79.865444
# 222792     207.0     17             0.013833  6.345222              79.865444
# 222793     207.0     17             0.013833  6.345222              79.865444
# 222794     207.0     17             0.013833  6.345222              79.865444
#
#         longterm_disease_andel  overweight_andel  t2d_patients  \
# 0                     0.358000          0.206333   3936.207344
# 1                     0.358000          0.206333   3936.207344
# 2                     0.358000          0.206333   3936.207344
# 3                     0.358000          0.206333   3936.207344
# 4                     0.358000          0.206333   3936.207344
# ...                        ...               ...           ...
# 222790                0.379111          0.231143   3873.451601
# 222791                0.379111          0.231143   3873.451601
# 222792                0.379111          0.231143   3873.451601
# 222793                0.379111          0.231143   3873.451601
# 222794                0.379111          0.231143   3873.451601
#
#         uddannelse_lang_amount    physical_activity YEAR_MONTH  SECTOR_CODE  \
# 0                 11845.819974  0,33866666666666667   202009.0            0
# 1                 11845.819974  0,33866666666666667   202008.0            0
# 2                 11845.819974  0,33866666666666667   202008.0            0
# 3                 11845.819974  0,33866666666666667   202008.0            0
# 4                 11845.819974  0,33866666666666667   202009.0            0
# ...                        ...                  ...        ...          ...
# 222790            12043.591696                0,334   202007.0            0
# 222791            12043.591696                0,334   202007.0            0
# 222792            12043.591696                0,334   202009.0            0
# 222793            12043.591696                0,334   202010.0            0
# 222794            12043.591696                0,334   202012.0            0
#
#         VOLUME    VALUE WHO_ATC_CODE  year month
# 0         -1.0  -603.65      A10BH01  2020    09
# 1          1.0   238.08      A10AC01  2020    08
# 2         10.0  4894.70      A10AE06  2020    08
# 3          3.0   891.87      A10AD01  2020    08
# 4         25.0  6907.75      A10AC01  2020    09
# ...        ...      ...          ...   ...   ...
# 222790     4.0  1266.88      A10BK03  2020    07
# 222791     0.0   -53.38      A10BD08  2020    07
# 222792   391.0  4301.00      A10BA02  2020    09
# 222793     1.0   278.88      A10BD08  2020    10
# 222794     3.0   981.30      A10BD20  2020    12
#
# [76099 rows x 17 columns]

# %% [markdown]
# #### One-hot encoding
#
# One-hot encoding has the advantage that is does not introduce any order between features like label encoding does, but the drawback that K different categories of a feature will be transformed into K or K-1 new features, and so the total number of features can become very large, which can hurt performance. For this reasons, if a feature has many categories, these categories are often grouped in straightforward (simply group rare categories) or clever (use domain knowledge to make groups)

# %% [markdown]
# We will one-hot encode the column 'WHO_ATC_CODE'
# ATC: The Anatomical Therapeutic Chemical code - a code assigned to medicine based on it organic structure and/or system

# %%
df_dropped['WHO_ATC_CODE'].nunique()
# Out:
# 47

# %%
## We need this function to do one-hot (or dummy) encoding
def do_dummy_encoding(dataframe, target_columns, prefix_list, drop_first = False):
    """
    For each cateogrical column with categories (l1,...,ln), this function transform the category into n ( if drop_first = False)
    or n-1 columns, where [0,0,...,0] represents l1,
    [1,0,...,0] rep. l2, [0,1,0,...,0] rep l3 etc
    """
    data = dataframe.copy()
    # Build dummy index dataframe
    dummy_columns = pd.get_dummies(data[target_columns], prefix = prefix_list, drop_first=drop_first)

    ## Append new columns to dataframe
    data = pd.concat([data, dummy_columns], axis = 1)

    ## Drop original columns
    data.drop(columns = target_columns, inplace=True)
    return data

# %%
onehot_cols = ['WHO_ATC_CODE']

for i, col in enumerate(onehot_cols):
    # Use onehot_cols[i] as prefix for the new columns
    # If drop_first = False, the first category will be included in the new columns
    # If drop_first = True, the first category will be dropped, meaning that
    #  if all new columns are 0, the category is the first one. This is the most
    #  efficient way of doing it, but it has the price that we have to remember that
    # the first category is represented like this
    df_dropped = do_dummy_encoding(df_dropped, col, onehot_cols[i], drop_first = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223701 entries, 0 to 223700
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   brick_nr                76127 non-null   float64
#  1   brick                   223701 non-null  object
#  2   blood clot in heart     76127 non-null   object
#  3   absence                 76127 non-null   object
#  4   life_expectancy_years   76127 non-null   object
#  5   longterm_disease_andel  76127 non-null   object
#  6   overweight_andel        76127 non-null   object
#  7   t2d_patients            76127 non-null   object
#  8   uddannelse_lang_amount  76127 non-null   object
#  9   physical_activity       76127 non-null   object
#  10  YEAR_MONTH              223673 non-null  float64
#  11  SECTOR_CODE             223673 non-null  object
#  12  VOLUME                  223701 non-null  float64
#  13  VALUE                   223701 non-null  float64
#  14  WHO_ATC_CODE            223673 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 25.6+ MB

# %%
df_dropped
# Out:
#         brick_nr  brick  blood clot in heart   absence  life_expectancy_years  \
# 0          308.0      5             0.013750  6.002000              80.925500
# 1          308.0      5             0.013750  6.002000              80.925500
# 2          308.0      5             0.013750  6.002000              80.925500
# 3          308.0      5             0.013750  6.002000              80.925500
# 4          308.0      5             0.013750  6.002000              80.925500
# ...          ...    ...                  ...       ...                    ...
# 222790     207.0     17             0.013833  6.345222              79.865444
# 222791     207.0     17             0.013833  6.345222              79.865444
# 222792     207.0     17             0.013833  6.345222              79.865444
# 222793     207.0     17             0.013833  6.345222              79.865444
# 222794     207.0     17             0.013833  6.345222              79.865444
#
#         longterm_disease_andel  overweight_andel  t2d_patients  \
# 0                     0.358000          0.206333   3936.207344
# 1                     0.358000          0.206333   3936.207344
# 2                     0.358000          0.206333   3936.207344
# 3                     0.358000          0.206333   3936.207344
# 4                     0.358000          0.206333   3936.207344
# ...                        ...               ...           ...
# 222790                0.379111          0.231143   3873.451601
# 222791                0.379111          0.231143   3873.451601
# 222792                0.379111          0.231143   3873.451601
# 222793                0.379111          0.231143   3873.451601
# 222794                0.379111          0.231143   3873.451601
#
#         uddannelse_lang_amount    physical_activity  ... WHO_ATC_CODE_A10BJ01  \
# 0                 11845.819974  0,33866666666666667  ...                False
# 1                 11845.819974  0,33866666666666667  ...                False
# 2                 11845.819974  0,33866666666666667  ...                False
# 3                 11845.819974  0,33866666666666667  ...                False
# 4                 11845.819974  0,33866666666666667  ...                False
# ...                        ...                  ...  ...                  ...
# 222790            12043.591696                0,334  ...                False
# 222791            12043.591696                0,334  ...                False
# 222792            12043.591696                0,334  ...                False
# 222793            12043.591696                0,334  ...                False
# 222794            12043.591696                0,334  ...                False
#
#         WHO_ATC_CODE_A10BJ02  WHO_ATC_CODE_A10BJ03  WHO_ATC_CODE_A10BJ05  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
# ...                      ...                   ...                   ...
# 222790                 False                 False                 False
# 222791                 False                 False                 False
# 222792                 False                 False                 False
# 222793                 False                 False                 False
# 222794                 False                 False                 False
#
#        WHO_ATC_CODE_A10BJ06 WHO_ATC_CODE_A10BK01  WHO_ATC_CODE_A10BK02  \
# 0                     False                False                 False
# 1                     False                False                 False
# 2                     False                False                 False
# 3                     False                False                 False
# 4                     False                False                 False
# ...                     ...                  ...                   ...
# 222790                False                False                 False
# 222791                False                False                 False
# 222792                False                False                 False
# 222793                False                False                 False
# 222794                False                False                 False
#
#         WHO_ATC_CODE_A10BK03  WHO_ATC_CODE_A10BK04  WHO_ATC_CODE_A10BX02
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
# ...                      ...                   ...                   ...
# 222790                  True                 False                 False
# 222791                 False                 False                 False
# 222792                 False                 False                 False
# 222793                 False                 False                 False
# 222794                 False                 False                 False
#
# [76099 rows x 63 columns]

# %%
diagnose_grupper = pd.read_csv('Tabel_SKS_Diagnose_hospital.csv', sep=";")
diagnose_grupper.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 diagnose_grupper = pd.read_csv('Tabel_SKS_Diagnose_hospital.csv', sep=";")
#       2 diagnose_grupper.info()
#
# NameError: name 'pd' is not defined
